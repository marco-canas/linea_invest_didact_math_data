# %% [markdown]
# Aquí tienes una **descripción del proyecto adaptada para el Plan de Gestión de Datos (PGD)** que solicita la Universidad de Antioquia en el marco de la presentación de proyectos al CODI. Este texto responde a los lineamientos típicos exigidos para este componente:
#
# ---
#
# ## **Plan de Gestión de Datos (PGD)**
#
# ### Proyecto: *Aplicación de Análisis Predictivo para la Gestión de Riesgos Climáticos en Cultivos de Arroz del Bajo Cauca*
#
# ### 1. **Resumen del proyecto en relación con la gestión de datos**
#
# El proyecto busca desarrollar una aplicación predictiva basada en técnicas de *machine learning* y *deep learning* para anticipar riesgos climáticos en cultivos de arroz del Bajo Cauca. Se integrarán datos agroclimáticos, edáficos y agronómicos, provenientes de fuentes institucionales (IDEAM, IGAC, FEDEARROZ), así como datos recolectados en campo. La gestión eficiente, segura y ética de estos datos es fundamental para el éxito del proyecto y para su posterior escalabilidad.
#
# ---
#
# ### 2. **Tipos de datos que se generarán o recopilarán**
#
# | Tipo de dato                                           | Fuente                   | Formato                       | Frecuencia               | Responsable            |
# | ------------------------------------------------------ | ------------------------ | ----------------------------- | ------------------------ | ---------------------- |
# | Datos climáticos históricos y en tiempo real           | IDEAM, estaciones piloto | CSV, JSON                     | Diario, mensual          | Estudiante / PI        |
# | Datos edáficos y topográficos                          | IGAC                     | SHP, GeoJSON, CSV             | Puntual                  | Estudiante / PI        |
# | Registros agrícolas (siembras, cosechas, rendimientos) | FEDEARROZ, encuestas     | CSV, XLSX                     | Estacional               | Estudiante / PI        |
# | Datos cualitativos de validación                       | Productores (ECAs)       | Audio, texto, transcripciones | Según fase de validación | Monitor comunitario    |
# | Resultados de modelos predictivos                      | Interno                  | .pkl, .ipynb, .csv            | Según avances            | Investigador principal |
#
# ---
#
# ### 3. **Procedencia y legalidad de los datos**
#
# Todos los datos utilizados tendrán origen legítimo y se regirán por la normatividad vigente:
#
# * **Ley 1712 de 2014** sobre el acceso a la información pública.
# * **Ley 1581 de 2012** sobre protección de datos personales.
# * Datos de entidades públicas (IDEAM, IGAC, FEDEARROZ) serán usados conforme a sus licencias de uso.
# * Para los datos recolectados en campo, se garantizará el **consentimiento informado**, el **anonimato** y el uso exclusivamente académico e institucional.
#
# ---
#
# ### 4. **Estrategias de almacenamiento, seguridad y respaldo**
#
# * Los datos serán almacenados de manera organizada en una **estructura jerárquica de carpetas** en servicios en la nube como **Google Drive institucional** y/o servidores de la UdeA.
# * Los archivos relevantes serán versionados mediante **Git/GitHub** y respaldados cada semana.
# * Se implementarán protocolos de seguridad:
#
#   * Accesos restringidos mediante autenticación de usuarios.
#   * Uso de contraseñas seguras para los dispositivos de adquisición de datos.
#   * Cifrado básico para almacenamiento sensible.
# * Los archivos con datos personales o sensibles serán anonimizados y protegidos por contraseña.
#
# ---
#
# ### 5. **Estrategias de documentación y metadatos**
#
# * Todos los conjuntos de datos serán acompañados de **archivos README** que incluyan:
#
#   * Fecha de recolección
#   * Fuente y responsable
#   * Formato
#   * Variables contenidas y unidades
# * Se emplearán esquemas de metadatos estándares como **Dublin Core** para describir los conjuntos de datos que se publiquen o compartan.
# * El código fuente será documentado con *docstrings* y *comentarios estándar* en Jupyter Notebooks.
#
# ---
#
# ### 6. **Política de uso y acceso a los datos**
#
# * Los datos abiertos (provenientes de entidades públicas) serán compartidos bajo licencia **Creative Commons CC-BY-NC-SA 4.0**.
# * Los datos generados en el proyecto, una vez procesados y anonimizados, serán **publicados en el repositorio GitHub del grupo GIBACC**.
# * Se prioriza la **ciencia abierta**, garantizando que otros investigadores puedan replicar, validar y reutilizar los resultados.
# * En caso de que algún dato no pueda ser compartido públicamente, se incluirá la justificación correspondiente (por ejemplo, acuerdos de confidencialidad con instituciones o agricultores).
#
# ---
#
# ### 7. **Preservación a largo plazo y reutilización de los datos**
#
# * Al finalizar el proyecto, los conjuntos de datos estructurados y validados serán depositados en el **Repositorio Institucional de la Universidad de Antioquia** o en repositorios de acceso abierto como **Zenodo** o **Figshare**, con DOI asignado.
# * Se elaborará una guía técnica para la reutilización de los datos y modelos, incluyendo:
#
#   * Requerimientos técnicos
#   * Ejemplos de uso
#   * Licencia
# * El código y la documentación completa se mantendrán en el repositorio público del proyecto (GitHub), permitiendo actualizaciones posteriores.
#
# ---
#
# ### 8. **Responsabilidades en la gestión de datos**
#
# | Rol                     | Nombre                     | Responsabilidades                                                           |
# | ----------------------- | -------------------------- | --------------------------------------------------------------------------- |
# | Investigador principal  | Marco Julio Cañas Campillo | Supervisión general del PGD, aseguramiento de calidad, publicación de datos |
# | Estudiante vinculado    | Por definir                | Recolección, procesamiento y documentación de datos                         |
# | Monitor de programación | Por definir                | Documentación de código, control de versiones                               |
# | Coordinador comunitario | Por definir                | Consentimiento informado y tratamiento ético de la información recolectada  |
#
# ---
#
# ### 9. **Recursos requeridos para la gestión de datos**
#
# * Licencias de software libre (Python, QGIS, Git).
# * Espacio en la nube institucional y cuentas de GitHub para control de versiones.
# * Dispositivos para recolección de datos en campo (tablets, sensores, estaciones meteorológicas).
# * Asesoría en ética de datos y protección de información.
#
# ---
#
# ### 10. **Indicadores de evaluación del PGD**
#
# | Indicador                                                  | Meta  | Frecuencia de revisión |
# | ---------------------------------------------------------- | ----- | ---------------------- |
# | Porcentaje de datos debidamente documentados               | ≥ 90% | Trimestral             |
# | Cumplimiento de respaldo y versión de datos                | 100%  | Mensual                |
# | Número de conjuntos de datos disponibles en acceso abierto | ≥ 3   | Al final del proyecto  |
# | Número de usuarios capacitados en gestión de datos         | ≥ 10  | En las ECAs            |
#
# ---
#
# ¿Deseas que te lo entregue también en formato **.docx** o **PDF**? ¿O que lo integre directamente a tu **formato PGD del CODI** si lo tienes?

# %%
from docx import Document
from docx.shared import Inches

# Crear el documento
doc = Document()
doc.add_heading('Plan de Gestión de Datos (PGD)', 0)

# Título del proyecto
doc.add_heading('Proyecto:', level=1)
doc.add_paragraph("Aplicación de Análisis Predictivo para la Gestión de Riesgos Climáticos en Cultivos de Arroz del Bajo Cauca")

# Sección 1
doc.add_heading("1. Resumen del proyecto en relación con la gestión de datos", level=2)
doc.add_paragraph("""
El proyecto busca desarrollar una aplicación predictiva basada en técnicas de machine learning y deep learning para anticipar riesgos climáticos en cultivos de arroz del Bajo Cauca. 
Para ello, se recopilarán datos climáticos, edáficos, agrícolas y sociales, y se entrenarán modelos con herramientas de ciencia de datos. 
Se seguirán principios de ciencia abierta, garantizando la calidad, seguridad, acceso y preservación de los datos generados o utilizados.
""")

# Sección 2
doc.add_heading("2. Tipos de datos que se generarán o recopilarán", level=2)
doc.add_paragraph("""
Se recopilarán y generarán los siguientes tipos de datos:
""")
doc.add_paragraph("""
- Datos climáticos (temperatura, precipitación, humedad relativa, velocidad del viento)
- Datos edáficos (tipo de suelo, pH, capacidad de retención de agua)
- Datos agrícolas (fechas de siembra/cosecha, variedades sembradas, rendimiento)
- Datos sociales y cualitativos (entrevistas con agricultores, percepciones del cambio climático)
- Modelos de predicción (archivos entrenados, scripts de entrenamiento, métricas de desempeño)
""")

# Sección 3
doc.add_heading("3. Procedencia y legalidad de los datos", level=2)
doc.add_paragraph("""
Los datos se obtendrán de:
- Datos públicos: IDEAM, IGAC, FEDEARROZ, plataformas de datos abiertos de MinCiencias y universidades
- Datos institucionales: Información recogida por el equipo investigador en trabajo de campo y con aliados
- Datos generados: Resultados de modelos, análisis y visualizaciones propias

El proyecto cumplirá con la Ley 1712 de 2014 (Transparencia y acceso a la información pública) y la Ley 1581 de 2012 (Protección de datos personales).
""")

# Sección 4
doc.add_heading("4. Estrategias de almacenamiento, seguridad y respaldo", level=2)
doc.add_paragraph("Los datos serán almacenados en entornos digitales seguros:")

doc.add_paragraph("""
- Datos brutos: Google Drive institucional con acceso restringido
- Datos procesados y modelos: Repositorio privado en GitHub (luego publicado)
- Datos sensibles: Carpeta cifrada, acceso restringido
- Respaldos: Semanales en discos externos institucionales y en la nube
- Registro de cambios: Control de versiones con Git
""")

# Sección 5
doc.add_heading("5. Estrategias de documentación y metadatos", level=2)
doc.add_paragraph("""
Se aplicarán estrategias de documentación estandarizadas:
""")
doc.add_paragraph("""
- README.md por cada conjunto de datos y notebook
- Metadatos estructurados usando Dublin Core
- Documentación de scripts y modelos con docstrings y comentarios
- Repositorio en GitHub incluirá Guía de usuario, Guía de instalación y Bitácora de versiones
""")

# Sección 6
doc.add_heading("6. Política de uso y acceso a los datos", level=2)
doc.add_paragraph("""
La política de uso se basará en principios de ciencia abierta y acceso responsable:
""")

# Agregar tabla de licencias
doc.add_paragraph("Licencias de uso:")
table1 = doc.add_table(rows=1, cols=2)
hdr_cells = table1.rows[0].cells
hdr_cells[0].text = 'Tipo de dato'
hdr_cells[1].text = 'Licencia'
table1.add_row().cells[0].text = 'Datos abiertos'
table1.rows[1].cells[1].text = 'CC BY-NC-SA 4.0'
table1.add_row().cells[0].text = 'Código fuente'
table1.rows[2].cells[1].text = 'MIT o GPLv3 (por definir)'
table1.add_row().cells[0].text = 'Publicaciones'
table1.rows[3].cells[1].text = 'Acceso abierto, DOI asociado'

# Sección 7
doc.add_heading("7. Preservación a largo plazo y reutilización de los datos", level=2)
doc.add_paragraph("""
Estrategias de preservación:
""")
doc.add_paragraph("""
- Publicación de datasets estructurados en Zenodo o Figshare con DOI
- Publicación de notebooks en GitHub y repositorios académicos
- Uso de formatos abiertos: CSV, JSON, NetCDF, Jupyter Notebook
""")

# Agregar tabla de repositorios
doc.add_paragraph("Repositorios de publicación:")
table2 = doc.add_table(rows=1, cols=2)
hdr = table2.rows[0].cells
hdr[0].text = "Repositorio"
hdr[1].text = "Tipo de contenido"
table2.add_row().cells[0].text = "GitHub"
table2.rows[1].cells[1].text = "Código, notebooks, documentación"
table2.add_row().cells[0].text = "Zenodo"
table2.rows[2].cells[1].text = "Datasets con DOI"
table2.add_row().cells[0].text = "Repositorio institucional"
table2.rows[3].cells[1].text = "Informe final, guías, documentos"

# Sección 8
doc.add_heading("8. Responsabilidades en la gestión de datos", level=2)
doc.add_paragraph("Responsabilidades distribuidas así:")

# Tabla de responsabilidades
doc.add_paragraph("Tabla de responsabilidades:")
table3 = doc.add_table(rows=1, cols=2)
header = table3.rows[0].cells
header[0].text = "Actor"
header[1].text = "Responsabilidad"
table3.add_row().cells[0].text = "Investigador principal"
table3.rows[1].cells[1].text = "Asegurar cumplimiento ético, calidad, publicación"
table3.add_row().cells[0].text = "Equipo de datos"
table3.rows[2].cells[1].text = "Recolección, limpieza, documentación, respaldo"
table3.add_row().cells[0].text = "Colaboradores"
table3.rows[3].cells[1].text = "Suministro de datos y validación en terreno"

# Sección 9
doc.add_heading("9. Recursos requeridos para la gestión de datos", level=2)
doc.add_paragraph("""
- Software: Python, R, Jupyter, QGIS, Git
- Hardware: Disco duro externo, sensores de campo (si aplica)
- Infraestructura: Google Drive institucional, GitHub, IDEs
- Recurso humano: Técnicos en ciencia de datos, estudiantes, investigadores
""")

# Sección 10
doc.add_heading("10. Indicadores de evaluación del PGD", level=2)

# Tabla de indicadores
table4 = doc.add_table(rows=1, cols=2)
head = table4.rows[0].cells
head[0].text = "Indicador"
head[1].text = "Meta"
table4.add_row().cells[0].text = "Porcentaje de datos documentados"
table4.rows[1].cells[1].text = "≥ 90%"
table4.add_row().cells[0].text = "N° de conjuntos de datos abiertos publicados"
table4.rows[2].cells[1].text = "≥ 3"
table4.add_row().cells[0].text = "Respaldo de datos"
table4.rows[3].cells[1].text = "Mensual"
table4.add_row().cells[0].text = "Capacitación en ECAs"
table4.rows[4].cells[1].text = "≥ 10 usuarios capacitados"

# Guardar documento
doc.save("pgd_con_tablas.docx")

# %%
from docx import Document
from docx.shared import Inches
from docx.enum.table import WD_TABLE_ALIGNMENT
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# Crear documento
doc = Document()
doc.add_heading('Tamaño Actual o Esperado del Conjunto de Datos', level=1)

# Párrafo introductorio
doc.add_paragraph(
    'En el proyecto “Aplicación de Análisis Predictivo para la Gestión de Riesgos Climáticos en Cultivos de Arroz del Bajo Cauca”, '
    'el tamaño actual o esperado del conjunto de datos puede estimarse a partir de las siguientes fuentes:'
)

# Tabla 1: Estimación del tamaño
doc.add_heading('📊 Estimación del tamaño actual o esperado de los datos', level=2)
table1 = doc.add_table(rows=1, cols=5)
table1.alignment = WD_TABLE_ALIGNMENT.CENTER
hdr_cells = table1.rows[0].cells
hdr_cells[0].text = 'Fuente de datos'
hdr_cells[1].text = 'Descripción'
hdr_cells[2].text = 'Periodo estimado'
hdr_cells[3].text = 'Frecuencia'
hdr_cells[4].text = 'Tamaño estimado'

data1 = [
    ['IDEAM (clima: temperatura, humedad, precipitación, etc.)',
     'Estaciones meteorológicas locales/regionales', '2007–2024', 'Diario (prom. 365 registros/año por estación)', '~100–300 MB por estación'],
    ['Antioquia Mira Su Cielo (sensores)',
     'Datos en tiempo real de temperatura, humedad, viento, etc.', '2017–2024', 'Horaria o diaria', '~500 MB – 1 GB'],
    ['Fedearroz',
     'Registros agronómicos y de producción de arroz', '2007–2024', 'Por ciclo o campaña', '~50–150 MB'],
    ['Secretaría de Salud (casos de enfermedades vectoriales)',
     'Casos reportados por municipio', '2007–2024', 'Mensual', '~20–50 MB'],
    ['Datos recolectados en campo (encuestas, imágenes, GPS)',
     'Fotos, formularios, notas, coordenadas geográficas', 'Proyecto piloto', 'Esporádico / por visita', '~2–5 GB'],
    ['Modelos y simulaciones',
     'Resultados de modelos ARIMA, SVM, RF, etc.', 'Producidos durante proyecto', 'Por simulación/modelo', '~100 MB – 1 GB'],
]

for row_data in data1:
    row = table1.add_row().cells
    for i, item in enumerate(row_data):
        row[i].text = item

# Espacio y nuevo encabezado
doc.add_paragraph()
doc.add_heading('📦 Tamaño total estimado del conjunto de datos', level=2)

# Lista con estimaciones
doc.add_paragraph('- Mínimo esperado: ~1.5 GB')
doc.add_paragraph('- Máximo esperado: ~7–10 GB  (dependiendo del número de estaciones, sensores, calidad de imágenes y cantidad de simulaciones generadas)')

# Encabezado de almacenamiento
doc.add_heading('📁 Almacenamiento', level=2)

# Lista de opciones de almacenamiento
doc.add_paragraph('- Repositorios de Google Drive o OneDrive para datos crudos y procesados.')
doc.add_paragraph('- GitHub para código, scripts y notebooks.')
doc.add_paragraph('- Bases de datos locales o en la nube (ej. SQLite, PostgreSQL, MongoDB).')
doc.add_paragraph('- YouTube (DiMathData) para documentación audiovisual de los procesos.')

# Guardar archivo
doc.save('Tamaño_datos_proyecto_arroz.docx')
print("Documento creado con éxito: 'Tamaño_datos_proyecto_arroz.docx'")
# Out:
# Documento creado con éxito: 'Tamaño_datos_proyecto_arroz.docx'

# %% [markdown]
# # Descripción corta de este proyecto
#
# ### **Descripción Breve del Proyecto para el Plan de Gestión de Datos**
#
# **Nombre del Proyecto:**
# *Aplicación de Análisis Predictivo para la Gestión de Riesgos Climáticos en Cultivos de Arroz del Bajo Cauca*
#
# **Objetivo General:**
# Desarrollar una aplicación basada en **machine learning** y **deep learning** para predecir riesgos climáticos (sequías, inundaciones) en cultivos de arroz del Bajo Cauca antioqueño, integrando datos agrícolas (hectáreas sembradas/cosechadas, producción) y climáticos (IDEAM, estaciones locales), con el fin de optimizar decisiones y promover la sostenibilidad agrícola.
#
# **Objetivos Específicos:**
# 1. **Integración de datos:** Consolidar una base unificada con variables climáticas y agrícolas.
# 2. **Modelado predictivo:** Implementar algoritmos (Random Forest, XGBoost, LSTM) para predecir impactos en productividad.
# 3. **Plataforma interactiva:** Crear una herramienta web/móvil con visualizaciones y recomendaciones accionables (ej: fechas óptimas de siembra).
# 4. **Validación en campo:** Ajustar modelos con cooperativas arroceras (Fedearroz) y feedback de agricultores.
# 5. **Transferencia tecnológica:** Capacitar a actores locales y publicar guías de uso abiertas.
#
# **Metodología (Enfoque STEAM):**
# - **Fase 1 (Co-diseño):** Análisis de datos históricos y diseño participativo con agricultores.
# - **Fase 2 (Desarrollo):** Uso de Python (Pandas, TensorFlow), APIs (IDEAM), y herramientas como Plotly Dash para visualización.
# - **Fase 3 (Validación):** Pruebas piloto en fincas y métricas de precisión (RMSE, AUC).
#
# **Impactos Esperados:**
# - Reducción del **20% en pérdidas** por eventos climáticos.
# - Incremento del **15% en productividad** mediante alertas tempranas.
# - Fortalecimiento de capacidades digitales en agricultores y replicabilidad a otros cultivos (maíz, plátano).
#
# **Aliados Clave:**
# - **Universidad de Antioquia (Sede Bajo Cauca):** Formación en ciencia de datos.
# - **Fedearroz e IDEAM:** Datos agronómicos y climáticos.
# - **Gobernación de Antioquia:** Políticas públicas y escalamiento.
#
# **Presupuesto:** $100 millones COP (incluye equipos, desarrollo de software, trabajo de campo y divulgación).
#
# **Innovación:**
# Combina **inteligencia artificial** con conocimiento local para generar resiliencia climática, alineándose con agendas de desarrollo territorial y educación STEM.
#
# **Palabras Clave:**
# Agricultura de precisión, cambio climático, machine learning, arroz, Bajo Cauca, predictibilidad agrícola.
#
# ---
# *Nota:* Este proyecto integra tecnología avanzada con participación comunitaria, asegurando sostenibilidad y apropiación social del conocimiento.

# %% [markdown]
# # Descripción del proyecto, incluyendo la finalidad de la recolección y creación de los datos
#
# ### **Descripción Ampliada del Proyecto para el Plan de Gestión de Datos**
#
# **Nombre del Proyecto:**
# *Aplicación de Análisis Predictivo para la Gestión de Riesgos Climáticos en Cultivos de Arroz del Bajo Cauca*
#
# #### **Finalidad de la Recopilación y Creación de Datos**
# La recopilación, integración y generación de datos en este proyecto tiene los siguientes propósitos estratégicos:
#
# 1. **Construir una Base de Datos Unificada:**
#    - Consolidar información histórica y en tiempo real sobre variables climáticas (precipitación, temperatura, humedad), datos agrícolas (hectáreas sembradas/cosechadas, rendimiento) y edáficos (suelos) para crear un repositorio accesible y estandarizado.
#    - Fuentes clave: IDEAM (datos meteorológicos), IGAC (suelos), Fedearroz (producción arrocera) y estaciones meteorológicas locales instaladas.
#
# 2. **Entrenar Modelos Predictivos Robustos:**
#    - Los datos recopilados permitirán alimentar algoritmos de **machine learning** (Random Forest, XGBoost) y **deep learning** (LSTM) para predecir riesgos climáticos (sequías, inundaciones) y su impacto en los cultivos.
#    - Se priorizará la calidad y representatividad de los datos para garantizar precisión en las predicciones.
#
# 3. **Generar Conocimiento Local Adaptado:**
#    - Complementar datos globales (ej: satelitales) con información hiperlocal recolectada en campo (encuestas a agricultores, mediciones en fincas piloto), asegurando que los modelos reflejen las condiciones reales del Bajo Cauca.
#    - Documentar prácticas tradicionales de manejo agrícola para enriquecer las recomendaciones de la aplicación.
#
# 4. **Soportar Decisiones Basadas en Evidencia:**
#    - Transformar datos crudos en **insumos accionables** (ej: alertas tempranas, fechas óptimas de siembra) mediante dashboards interactivos, facilitando la planificación agrícola.
#    - Garantizar que los datos sean interpretables para usuarios no técnicos (agricultores, extensionistas).
#
# 5. **Sustentar Políticas Públicas y Escalamiento:**
#    - Los resultados del análisis de datos servirán como insumo para entidades como la **Secretaría de Agricultura de Antioquia** o el **ICA**, promoviendo estrategias regionales de adaptación climática.
#    - Los conjuntos de datos generados se publicarán bajo licencias abiertas (cuando sea posible) para fomentar la replicabilidad en otros cultivos o regiones.
#
# ---
#
# #### **Objetivo General**
# Desarrollar una aplicación basada en **machine learning** y **deep learning** para predecir riesgos climáticos (sequías, inundaciones) en cultivos de arroz del Bajo Cauca antioqueño, integrando datos agrícolas y climáticos, con el fin de optimizar decisiones y promover la sostenibilidad agrícola.
#
# #### **Metodología (Enfoque STEAM)**
# - **Fase 1 (Co-diseño):** Diagnóstico participativo con agricultores y recolección de datos históricos.
# - **Fase 2 (Desarrollo):** Procesamiento con Python (Pandas, TensorFlow), APIs (IDEAM), y visualización en Plotly Dash.
# - **Fase 3 (Validación):** Pruebas piloto en fincas con métricas de precisión (RMSE, AUC).
#
# #### **Impactos Esperados**
# - Reducción del **20% en pérdidas** por eventos climáticos.
# - Incremento del **15% en productividad** mediante alertas tempranas.
# - Modelo replicable a otros cultivos (maíz, plátano) y regiones.
#
# **Aliados Clave:** Universidad de Antioquia, Fedearroz, IDEAM, Gobernación de Antioquia.
# **Presupuesto:** $100 millones COP (incluye equipos, desarrollo, capacitación y divulgación).
#
# ---
# **Palabras Clave:**
# Agricultura de precisión, cambio climático, inteligencia artificial, gestión de datos, arroz, Bajo Cauca.
#
# *Nota:* El proyecto no solo recopila datos, sino que los convierte en **herramientas prácticas** para la resiliencia climática, combinando tecnología avanzada con participación comunitaria.*
