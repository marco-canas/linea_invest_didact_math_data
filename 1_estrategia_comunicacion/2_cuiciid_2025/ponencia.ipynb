# %% [markdown]
# [Normativa de envío de Ponencia CUIDIID 2025](https://cuiciid.net/ponencias-2025/)

# %% [markdown]
# Fecha tope de envío:
# Lunes 7 de julio de 2025
#
# Idiomas y Extensión:
#
# Libro electrónico de la “Colección Académica Iberoamericana del siglo XXI” indizado en SCOPUS BOOKS INDEX de acceso libre. Obligatorio en inglés, máximo 10 páginas todo incluido.
# Libro electrónico de la colección “Innovación y Formación” de la editorial ARCO-LA MURALLA (indizada en SPI Q1). Cualquier idioma oficial del congreso (Español, portugués, italiano, inglés o francés. Puede ser distinto al del resumen), máximo 14 páginas todo incluido.
#
# Esquema:
# Si se trata de un artículo de investigación debe tener los siguientes apartados:
# INTRODUCCIÓN, OBJETIVOS, MARCO TEÓRICO, METODOLOGÍA, RESULTADOS-DISCUSIÓN, CONCLUSIONES y REFERENCIAS (Normas APA 7ª).
#
# Y si se trata de un artículo de revisión:
# INTRODUCCIÓN, MATERIALES, MÉTODOS, RESULTADOS-DISCUSIÓN o CONCLUSIONES, REFERENCIAS (Normas APA 7ª).
#
# Las Normas APA 7ª se seguirán en las citas en el texto y en el apartado de referencias. Para el resto de la maquetación (márgenes, párrafos, sangrado, etc.) se seguirán las Normas indicadas en la plantilla.
# Normas APA 7ª
# Por favor, es imprescindible que envíen la versión sin el control de cambios activado, es decir, ha de ser enviada la versión final para publicar siempre en WORD .docx o .doc, NUNCA en .pdf.
