# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/linea_invest_didact_math_data/blob/main/1_estrategia_comunicacion/4_jornadas_inv_2025/1_aplicaciones_python_inv_cualitativa/2_entrevistas/2_entrevistas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/linea_invest_didact_math_data/blob/main/1_estrategia_comunicacion/4_jornadas_inv_2025/1_aplicaciones_python_inv_cualitativa/2_entrevistas/2_entrevistas.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
import qrcode
from IPython.display import display

def generar_qr_notebook(url):
    """
    Genera un código QR para una URL y lo muestra en un cuaderno Jupyter.
    
    Parámetros:
    url (str): La URL para la cual se generará el código QR.
    
    Retorna:
    None (pero muestra el código QR en el notebook)
    """
    # Crear el objeto QR
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )
    
    # Añadir la URL al código QR
    qr.add_data(url)
    qr.make(fit=True)
    
    # Crear la imagen del QR
    img = qr.make_image(fill_color="black", back_color="white")
    
    # Mostrar la imagen en el notebook
    display(img)

# %%
url = 'https://colab.research.google.com/github/marco-canas/linea_invest_didact_math_data/blob/main/1_estrategia_comunicacion/4_jornadas_inv_2025/1_aplicaciones_python_inv_cualitativa/2_entrevistas/2_entrevistas.ipynb'
generar_qr_notebook(url)

# %% [markdown]
# # Herramientas de Python para Investigación Cualitativa en Administración de Empresas

# %% [markdown]
# ## Caso de Estudio: **Análisis de Entrevistas**

# %% [markdown]
# # **Objetivos del Taller**

# %% [markdown]
# * Introducir al uso de Python en la investigación cualitativa.

# %% [markdown]
# * Aplicar técnicas de procesamiento de texto a entrevistas realizadas en el marco de investigaciones empresariales.

# %% [markdown]
# * Mostrar ejemplos prácticos de análisis de entrevistas con herramientas digitales para complementar el análisis manual.

# %% [markdown]
# # **1. Introducción a la investigación cualitativa asistida con Python**

# %% [markdown]
# # * Conceptos básicos: entrevistas, codificación, patrones temáticos.

# %% [markdown]
# # 1. Entrevistas
#
#
# Son una técnica de recolección de información cualitativa que busca comprender las percepciones, experiencias, ideas o significados que las personas atribuyen a un fenómeno.
# En investigación educativa, social o administrativa, se utilizan para obtener **discursos ricos y detallados** sobre un tema.

# %% [markdown]
# ### Tipos comunes
#
# * **Estructuradas:** preguntas fijas, iguales para todos los entrevistados.
# * **Semiestructuradas:** combinan preguntas guía con la posibilidad de explorar respuestas emergentes (las más usadas en investigación cualitativa).
# * **No estructuradas:** el diálogo fluye libremente; útiles en etapas exploratorias.

# %% [markdown]
# ### Objetivo
#
# Capturar **la voz del participante** para luego analizar su discurso y **extraer significados**, categorías y patrones.
#
# ---

# %% [markdown]
# # 2. Codificación
#
#
# La **codificación** es el proceso de **asignar etiquetas o códigos** a fragmentos de texto (palabras, frases, párrafos) que representan una idea o categoría relevante para la investigación.

# %% [markdown]
# En otras palabras, **traducimos el lenguaje natural a datos analíticos**.
# Ejemplo:
#
# > Fragmento: “Me gusta trabajar con Python porque facilita el análisis de datos.”
# > Código: `motivación_aprendizaje`, `uso_Python`, `análisis_datos`

# %% [markdown]
# ### En Python
#
# * Se pueden **automatizar partes del proceso** con herramientas de análisis de texto, por ejemplo:
#
#   * `nltk` o `spaCy` para tokenizar y limpiar el texto.
#   * `TfidfVectorizer` o `CountVectorizer` (de `scikit-learn`) para representar el discurso como una matriz numérica.
#   * Algoritmos de **clustering (como KMeans)** para agrupar respuestas similares.
#
# Esto no reemplaza la interpretación humana, pero **ayuda a organizar, reducir y visualizar** grandes volúmenes de texto.
#
# ---

# %% [markdown]
# # 3. Patrones temáticos
#
# Los **patrones temáticos** (o *temas*) son **ideas recurrentes o significativas** que emergen de los datos codificados.
# Un **tema** sintetiza múltiples fragmentos de discurso en una **explicación interpretativa**.

# %% [markdown]
# Ejemplo:
#
# * Tema: *Uso de la tecnología para aprender mejor*
#
#   * Códigos relacionados: `uso_Python`, `autonomía_digital`, `motivación_aprendizaje`.
#
# ### Análisis temático
#
# Es el proceso de identificar, analizar y reportar **patrones de significado** dentro de los datos.
# Se suelen seguir las fases propuestas por Braun y Clarke (2006):
#
# 1. Familiarización con los datos.
# 2. Generación de códigos iniciales.
# 3. Búsqueda de temas.
# 4. Revisión de temas.
# 5. Definición y nombramiento de temas.
# 6. Elaboración del informe.

# %% [markdown]
# ### En Python
#
# El análisis temático puede apoyarse con:
#
# * **Frecuencia de palabras o nubes de palabras** (`wordcloud`, `Counter` de `collections`).
# * **Modelos de tópicos** como *Latent Dirichlet Allocation (LDA)* para descubrir temas latentes.
# * **Agrupamientos** (*clustering*) por similitud semántica con `KMeans` o `AgglomerativeClustering`.
# * **Visualizaciones** con `matplotlib`, `seaborn` o `plotly` para mostrar relaciones entre temas y categorías.
#
# ---

# %% [markdown]
# # Relación entre los tres conceptos
#
# | Fase | Concepto               | Actividad                               | Ejemplo en Python                                    |
# | ---- | ---------------------- | --------------------------------------- | ---------------------------------------------------- |
# | 1    | **Entrevista**         | Recolectar los discursos                | `df = pd.read_csv("entrevistas.csv")`                |
# | 2    | **Codificación**       | Etiquetar o agrupar palabras y frases   | `vectorizer = TfidfVectorizer(stop_words='spanish')` |
# | 3    | **Patrones temáticos** | Identificar temas o clusters de sentido | `KMeans(n_clusters=3).fit(X)`                        |
#
# ---

# %% [markdown]
# # * Python como herramienta de apoyo para explorar y organizar información textual.

# %% [markdown]
# # Python como herramienta de apoyo para explorar y organizar información textual
#
# En la investigación cualitativa, los textos (como entrevistas, diarios, observaciones o discursos) contienen una gran cantidad de información rica en significados.

# %% [markdown]
# Sin embargo, cuando se trabaja con **muchas entrevistas o respuestas abiertas**, el análisis manual puede resultar lento y difícil de sistematizar.

# %% [markdown]
# Aquí es donde **Python** se convierte en un aliado valioso.
#
# ---

# %% [markdown]
# # ¿Por qué usar Python en análisis textual?
#
# Python es un lenguaje de programación versátil, gratuito y con una amplia comunidad científica. Dispone de **bibliotecas especializadas en procesamiento de lenguaje natural (PLN)** que permiten:
#
# 1. **Explorar** el texto (ver su estructura, frecuencia de palabras, longitud, etc.).
# 2. **Organizar** los datos textuales en tablas o matrices numéricas.
# 3. **Detectar patrones** de uso de palabras, temas o emociones.
# 4. **Visualizar** relaciones entre conceptos, mediante nubes de palabras.
# 5. **Complementar el análisis interpretativo** del investigador, no reemplazarlo.
#
# ---

# %% [markdown]
# # 1. Exploración y limpieza del texto

# %% [markdown]
# El primer paso en el análisis textual es **preparar el corpus**, es decir, limpiar y normalizar las entrevistas.
# Python permite automatizar esta tarea fácilmente con librerías como:
#
# * **`pandas`** → para almacenar y manipular entrevistas en un DataFrame.
# * **`re`** (expresiones regulares) → para eliminar símbolos o caracteres innecesarios.
# * **`nltk`** o **`spaCy`** → para tokenizar (dividir el texto en palabras), convertir a minúsculas, eliminar “stopwords” y lematizar.

# %% [markdown]
# **Ejemplo:**

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# Cargar entrevistas
df = pd.read_csv("entrevistas.csv")

# Limpieza básica
stop_words = stopwords.words('spanish')
df["texto_limpio"] = df["entrevista"].str.lower()
df["texto_limpio"] = df["texto_limpio"].apply(
    lambda x: " ".join([w for w in x.split() if w not in stop_words])
)

# %% [markdown]
# 👉 Esto convierte cada entrevista en una versión más uniforme y analizable.
#
# ---

# %% [markdown]
# ### 🔍 2. Representación y organización de la información
#
# Una vez limpio el texto, se puede **convertir en una estructura cuantificable** (sin perder su esencia cualitativa).
# Python ofrece herramientas como:
#
# * **`CountVectorizer`** o **`TfidfVectorizer`** (de `scikit-learn`) para transformar el texto en una **matriz de frecuencias o pesos**.
# * Esto permite medir la importancia de cada palabra o término dentro del conjunto de entrevistas.
#
# **Ejemplo:**
#
# ```python
# from sklearn.feature_extraction.text import TfidfVectorizer
#
# vectorizer = TfidfVectorizer(stop_words='spanish')
# X = vectorizer.fit_transform(df["texto_limpio"])
# ```
#
# Ahora `X` contiene una **representación numérica del contenido textual**, lista para aplicar métodos de agrupamiento o análisis temático.
#
# ---

# %% [markdown]
# ### 🧩 3. Agrupación y detección de temas
#
# Python también permite **agrupar discursos similares** o identificar **temas emergentes** mediante técnicas de *machine learning*:
#
# * **KMeans** (agrupamiento por similitud de palabras o ideas).
# * **LDA (Latent Dirichlet Allocation)** para detectar **tópicos latentes** en un corpus extenso.

# %% [markdown]
# **Ejemplo:**

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
df["Cluster"] = kmeans.fit_predict(X)

# %% [markdown]
# Cada entrevista queda clasificada dentro de un **grupo temático**, que el investigador puede luego **interpretar y nombrar** cualitativamente.
#
# ---

# %% [markdown]
# # 4. Visualización e interpretación
#
# Finalmente, Python permite **visualizar** las relaciones textuales para facilitar la interpretación:
#
# * **`wordcloud`** → nubes de palabras más frecuentes.
# * **`matplotlib` / `seaborn` / `plotly`** → gráficos interactivos de temas o frecuencias.
# * **`networkx`** → redes semánticas o coocurrencias de palabras.
#
# **Ejemplo:**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

texto_total = " ".join(df["texto_limpio"])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(texto_total)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # En resumen
#
# | Etapa         | Objetivo                               | Herramientas Python                  | Resultado                           |
# | ------------- | -------------------------------------- | ------------------------------------ | ----------------------------------- |
# | Exploración   | Observar el corpus y limpiar el texto  | `pandas`, `nltk`, `spaCy`            | Texto uniforme y limpio             |
# | Organización  | Transformar texto en datos analizables | `TfidfVectorizer`, `CountVectorizer` | Matriz de características textuales |
# | Análisis      | Detectar similitudes o temas           | `KMeans`, `LDA`                      | Agrupamientos o tópicos             |
# | Visualización | Representar patrones de significado    | `wordcloud`, `matplotlib`, `plotly`  | Gráficos interpretativos            |
#
# ---

# %% [markdown]
# # Enfoque pedagógico
#
# En el contexto de tu taller, Python puede presentarse como un **instrumento de mediación tecnológica** que:
#
# * **Facilita la sistematización** del análisis cualitativo.
# * **Complementa la interpretación humana** con evidencia cuantitativa.
# * **Promueve el pensamiento computacional** al vincular lectura crítica y modelado de texto.

# %% [markdown]
# ### **3. Cargar y explorar entrevistas**
#
# Ejemplo: entrevistas a estudiantes de Administración sobre **“retos en la práctica empresarial”**.

# %%
import pandas as pd

# Simulación de dataset con respuestas de entrevistas
data = {
    "Entrevistado": ["E1", "E2", "E3", "E4"],
    "Respuesta": [
        "En mi práctica empresarial, el mayor reto fue la falta de comunicación entre áreas.",
        "Considero que la gestión del tiempo fue lo más difícil durante la práctica.",
        "El reto principal estuvo en la toma de decisiones bajo presión.", 
        "La toma de decisiones es difícil y requiere información y técnica"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#   Entrevistado                                          Respuesta
# 0           E1  En mi práctica empresarial, el mayor reto fue ...
# 1           E2  Considero que la gestión del tiempo fue lo más...
# 2           E3  El reto principal estuvo en la toma de decisio...
# 3           E4  La toma de decisiones es difícil y requiere in...

# %% [markdown]
# # **4. Limpieza y preprocesamiento de texto**
#
# * Convertir a minúsculas
# * Eliminar signos de puntuación
# * Quitar *stopwords* en español

# %%
import nltk
import re
from nltk.corpus import stopwords

nltk.download("stopwords")
stop_words = set(stopwords.words("spanish"))

def limpiar_texto(texto):
    texto = texto.lower()
    texto = re.sub(r"[^a-záéíóúñ\s]", "", texto)
    palabras = [p for p in texto.split() if p not in stop_words]
    return " ".join(palabras)

df["Respuesta_limpia"] = df["Respuesta"].apply(limpiar_texto)
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   Entrevistado                                          Respuesta  \
# 0           E1  En mi práctica empresarial, el mayor reto fue ...
# 1           E2  Considero que la gestión del tiempo fue lo más...
# 2           E3  El reto principal estuvo en la toma de decisio...
# 3           E4  La toma de decisiones es difícil y requiere in...
#
#                                     Respuesta_limpia
# 0  práctica empresarial mayor reto falta comunica...
# 1          considero gestión tiempo difícil práctica
# 2        reto principal toma decisiones bajo presión
# 3  toma decisiones difícil requiere información t...

# %% [markdown]
# # **5. Análisis exploratorio de las entrevistas**

# %% [markdown]
# #### a) Frecuencia de palabras

# %%
from collections import Counter

palabras = " ".join(df["Respuesta_limpia"]).split()
conteo = Counter(palabras)
conteo.most_common(5)
# Out:
# [('práctica', 2), ('reto', 2), ('difícil', 2), ('toma', 2), ('decisiones', 2)]

# %% [markdown]
# ## b) Visualización: nube de palabras

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

texto = " ".join(df["Respuesta_limpia"])
wc = WordCloud(width=800, height=600, background_color="white").generate(texto)

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ---
#
# ### **6. Identificación de temas (TF-IDF y clustering simple)**
#
# Ejemplo: extraer temas comunes en las entrevistas.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["Respuesta_limpia"])

kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)

df["Cluster"] = kmeans.labels_
df
# Out:
#   Entrevistado                                          Respuesta  \
# 0           E1  En mi práctica empresarial, el mayor reto fue ...
# 1           E2  Considero que la gestión del tiempo fue lo más...
# 2           E3  El reto principal estuvo en la toma de decisio...
# 3           E4  La toma de decisiones es difícil y requiere in...
#
#                                     Respuesta_limpia  Cluster
# 0  práctica empresarial mayor reto falta comunica...        0
# 1          considero gestión tiempo difícil práctica        0
# 2        reto principal toma decisiones bajo presión        1
# 3  toma decisiones difícil requiere información t...        1

# %% [markdown]
# # **7. Interpretación de resultados**

# %% [markdown]
# * **Cluster 0:** Palabras asociadas con “gestión del tiempo y comunicación”.
# * **Cluster 1:** Palabras asociadas con “toma de decisiones y presión”.
#
# Discusión: cómo estos temas se relacionan con problemáticas reales de la práctica empresarial en Administración de Empresas.
#
# ---

# %% [markdown]
# # **Ejemplo de aplicación en Administración de Empresas**

# %% [markdown]
# * Investigación cualitativa sobre **“competencias blandas en la práctica empresarial”**.
# * Entrevistas a estudiantes, egresados y empresarios.
# * Python se usa para:
#
#   * Identificar los temas más frecuentes en las entrevistas.
#   * Comparar percepciones de distintos grupos.
#   * Visualizar patrones (ej. retos en gestión del tiempo, comunicación, liderazgo).

# %% [markdown]
# # **Actividad práctica**
#
# 1. Cada estudiante carga un archivo `.csv` con entrevistas de un tema empresarial de interés.
# 2. Aplica el flujo: limpieza → análisis de palabras → nube de palabras → clustering.
# 3. Presenta en clase una interpretación corta de los resultados en relación con la Administración de Empresas.
#
# ---

# %% [markdown]
# # **Cierre**
#
# * La investigación cualitativa en Administración de Empresas se enriquece con herramientas de Python.
# * Python no reemplaza el análisis interpretativo, sino que lo **complementa** y facilita la identificación de patrones.
# * Se promueve la integración de competencias digitales y pensamiento crítico en la formación empresarial.

# %% [markdown]
# # from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# El módulo `TfidfVectorizer` de **scikit-learn** (`from sklearn.feature_extraction.text import TfidfVectorizer`) es una herramienta muy útil para transformar texto en datos numéricos que pueden ser analizados estadística o computacionalmente.

# %% [markdown]
# Aunque proviene del campo del **procesamiento del lenguaje natural (NLP)**, su uso se ha extendido a la **investigación cualitativa** —por ejemplo, para el análisis de entrevistas, grupos focales o diarios de campo—, ya que permite **cuantificar patrones de lenguaje y temas emergentes**.

# %% [markdown]
# # 1. Qué es el `TfidfVectorizer`
#
# `TfidfVectorizer` significa **Term Frequency–Inverse Document Frequency Vectorizer**.
# Es una técnica de representación de texto que mide **la importancia relativa de una palabra en un documento dentro de un conjunto de documentos**.

# %% [markdown]
# La idea es simple:
#
# * **TF (Term Frequency)**: mide cuántas veces aparece una palabra en un documento.
#   $$
#   TF(t, d) = \frac{\text{Número de veces que aparece el término } t \text{ en el documento } d}{\text{Número total de términos en } d}
#   $$

# %% [markdown]
# * **IDF (Inverse Document Frequency)**: mide cuán exclusiva es una palabra en todo el conjunto de documentos.
#   $$
#   IDF(t) = \log\left(\frac{N}{1 + n_t}\right)
#   $$
#   donde $N$ es el número total de documentos y $n_t$ es el número de documentos que contienen el término $t$.

# %% [markdown]
# * **TF-IDF** es el producto de ambos:
#   $$
#   TFIDF(t, d) = TF(t, d) \times IDF(t)
#   $$
#   Cuanto más frecuente sea una palabra en un documento y menos frecuente en el resto, **mayor será su peso TF-IDF**.

# %% [markdown]
# # 2. Aplicación en análisis de entrevistas cualitativas
#
# En **investigación cualitativa**, este vectorizador puede servir como puente entre los enfoques interpretativos y los cuantitativos. Algunas aplicaciones concretas son:

# %% [markdown]
# ## a) Identificación de temas y patrones de lenguaje
#
# Si tienes varias entrevistas transcritas, `TfidfVectorizer` te permite cuantificar la frecuencia relativa de palabras clave por entrevista.
# Por ejemplo:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# Ejemplo de corpus de entrevistas
corpus = [
    "Los estudiantes sienten ansiedad frente a los exámenes.",
    "La motivación depende del acompañamiento del docente.",
    "Los estudiantes muestran mayor interés cuando hay actividades prácticas."
]

vectorizer = TfidfVectorizer(stop_words='spanish')
X = vectorizer.fit_transform(corpus)

df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
df

# %% [markdown]
# Esto genera una **matriz TF-IDF** donde las filas representan entrevistas y las columnas palabras relevantes.
# Podrás observar qué términos son más distintivos de cada discurso.
#
# ---

# %% [markdown]
# ## b) Agrupación o segmentación de discursos (clustering)
#
# Puedes aplicar técnicas como **K-Means**, **DBSCAN**, o **jerárquicas** para descubrir grupos de entrevistas con similitudes temáticas.
# Ejemplo:

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=42)
df["cluster"] = kmeans.fit_predict(X)

# %% [markdown]
# Esto puede revelar, por ejemplo, que **un grupo de entrevistados habla más de “motivación y acompañamiento”** y otro más de **“ansiedad y evaluación”**.
#
# ---

# %% [markdown]
# # c) Visualización de temas
#
# Puedes usar la matriz TF-IDF para crear **nubes de palabras ponderadas** o mapas semánticos (p. ej., con `wordcloud` o `plotly`), donde las palabras con mayor peso TF-IDF se muestran más grandes o más centrales.

# %% [markdown]
# ## d) Apoyo a la codificación temática
#
# En vez de sustituir la interpretación cualitativa, `TfidfVectorizer` puede **complementarla**:
#
# * Ayuda a **identificar códigos emergentes** de manera inductiva.
# * Permite **contrastar la frecuencia relativa de categorías** identificadas manualmente.
# * Facilita **la triangulación de resultados** entre análisis humano y análisis asistido por computadora.
#
# ---

# %% [markdown]
# # 3. Recomendaciones metodológicas

# %% [markdown]
# 1. **Preprocesamiento textual**:
#
#    * Elimina signos de puntuación, números, y palabras vacías (`stopwords`).
#    * Usa lematización o stemming (por ejemplo, con `spaCy` o `NLTK`).

# %% [markdown]
# 2. **Triangulación interpretativa**:
#    Utiliza los resultados TF-IDF como guía para volver al texto original, interpretar contextos y matices.

# %% [markdown]
# 3. **Complementariedad cuali-cuantitativa**:
#    Combina TF-IDF con técnicas de **análisis de contenido temático o fenomenológico**, asegurando que las inferencias mantengan la profundidad interpretativa del discurso.

# %% [markdown]
# 4. **Transparencia y reproducibilidad**:
#    Documenta tu pipeline de análisis (por ejemplo, en un cuaderno Jupyter) para favorecer la **ciencia abierta** y la **replicabilidad** de tu investigación.

# %% [markdown]
# # 4. Ejemplo de aplicación práctica

# %% [markdown]
# Imagina que estás investigando **las emociones de los estudiantes ante la evaluación**.
# Tienes 20 entrevistas. Puedes:
#
# 1. Cargar las transcripciones en un `DataFrame`.
# 2. Aplicar `TfidfVectorizer` con `stop_words='spanish'`.
# 3. Usar `KMeans` o `LatentDirichletAllocation` para agrupar los discursos.
# 4. Interpretar cada grupo según sus palabras más representativas.
# 5. Relacionar los resultados con las categorías teóricas (ansiedad, motivación, autoeficacia, etc.).

# %% [markdown]
# # **Análisis de entrevistas con TF-IDF y K-Means en investigación cualitativa**

# %%
# ============================================
# Análisis de entrevistas cualitativas con TF-IDF y K-Means
# Tema: Emociones de los estudiantes frente a la evaluación
# Autor: Marco Julio Cañas
# ============================================

# 1. Importar librerías
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# 2. Corpus de entrevistas simuladas
entrevistas = [
    "Me siento muy nervioso antes de los exámenes, temo no recordar lo que estudié.",
    "Cuando el profesor explica bien, me siento más tranquilo durante la evaluación.",
    "La ansiedad me bloquea y no puedo concentrarme al responder.",
    "Siento motivación cuando los exámenes son prácticos y relacionados con la vida real.",
    "Me frustra cuando no entiendo lo que me preguntan en el examen.",
    "Disfruto los exámenes cuando puedo aplicar lo aprendido en proyectos.",
    "Tengo miedo a equivocarme y que el profesor piense que no estudié.",
    "Me gusta cuando el profesor nos da retroalimentación después de la prueba.",
    "Pierdo el interés cuando las evaluaciones son solo de memoria.",
    "Me siento más confiado cuando estudio con mis compañeros."
]

df = pd.DataFrame({"Entrevista": entrevistas})
df
# Out:
#                                           Entrevista
# 0  Me siento muy nervioso antes de los exámenes, ...
# 1  Cuando el profesor explica bien, me siento más...
# 2  La ansiedad me bloquea y no puedo concentrarme...
# 3  Siento motivación cuando los exámenes son prác...
# 4  Me frustra cuando no entiendo lo que me pregun...
# 5  Disfruto los exámenes cuando puedo aplicar lo ...
# 6  Tengo miedo a equivocarme y que el profesor pi...
# 7  Me gusta cuando el profesor nos da retroalimen...
# 8  Pierdo el interés cuando las evaluaciones son ...
# 9  Me siento más confiado cuando estudio con mis ...

# %% [markdown]
# # 3. Vectorización con **TF-IDF**

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# Descargar stopwords si no las tienes
import nltk
nltk.download('stopwords')

# Cargar stopwords en español
spanish_stopwords = stopwords.words('spanish')

# Crear vectorizador TF-IDF con stopwords en español
vectorizer = TfidfVectorizer(stop_words=spanish_stopwords)

# Transformar el texto a una matriz numérica
X = vectorizer.fit_transform(df["Entrevista"].astype(str))  # Asegura que sean strings

# Convertir a DataFrame para observar las palabras y sus pesos
tfidf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
tfidf_df.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    ansiedad  aplicar  aprendido      bien   bloquea  compañeros  concentrarme  \
# 0  0.000000      0.0        0.0  0.000000  0.000000         0.0      0.000000
# 1  0.000000      0.0        0.0  0.447645  0.000000         0.0      0.000000
# 2  0.460158      0.0        0.0  0.000000  0.460158         0.0      0.460158
# 3  0.000000      0.0        0.0  0.000000  0.000000         0.0      0.000000
# 4  0.000000      0.0        0.0  0.000000  0.000000         0.0      0.000000
#
#    confiado   da  después  ...      real  recordar  relacionados  responder  \
# 0       0.0  0.0      0.0  ...  0.000000  0.460628      0.000000   0.000000
# 1       0.0  0.0      0.0  ...  0.000000  0.000000      0.000000   0.000000
# 2       0.0  0.0      0.0  ...  0.000000  0.000000      0.000000   0.460158
# ...

# %% [markdown]
# **Interpretación:**
# Cada fila representa una entrevista y cada columna una palabra relevante.
# Los valores indican **qué tan distintiva** es una palabra en esa entrevista.
#
# ---

# %% [markdown]
# # 4. Agrupar entrevistas según similitud semántica con **K-Means**

# %%
# Aplicar K-Means (2 grupos)
kmeans = KMeans(n_clusters=2, random_state=42)
df["Cluster"] = kmeans.fit_predict(X)

df

# %% [markdown]
# **Interpretación:**
# El algoritmo ha agrupado las entrevistas en **dos grupos semánticos**.
# Por ejemplo:
#
# * Cluster 0 → entrevistas centradas en **ansiedad, nervios y miedo**.
# * Cluster 1 → entrevistas centradas en **motivación, comprensión y disfrute**.

# %% [markdown]
# ## 5. Analizar las palabras más representativas de cada cluster

# %%
# Identificar palabras representativas por cluster
import numpy as np

palabras = vectorizer.get_feature_names_out()
clusters = kmeans.labels_

# Promedio de TF-IDF por cluster
mean_tfidf = X.toarray().T.dot(pd.get_dummies(clusters)) / np.bincount(clusters)

for i in range(kmeans.n_clusters):
    top_idx = mean_tfidf[:, i].argsort()[::-1][:10]
    top_words = [palabras[j] for j in top_idx]
    print(f"\n Cluster {i} - Palabras clave:")
    print(", ".join(top_words))

# %% [markdown]
# # 6. Visualización: Nubes de palabras por grupo

# %%
# Crear nubes de palabras por cluster
for i in range(kmeans.n_clusters):
    texto_cluster = " ".join(df[df["Cluster"] == i]["Entrevista"])
    nube = WordCloud(width=800, height=400, background_color='white', \
        colormap='plasma').generate(texto_cluster)
    plt.figure(figsize=(8,4))
    plt.imshow(nube, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"Nube de palabras - Cluster {i}")
    plt.show()

# %% [markdown]
# **Interpretación visual:**
# Cada nube muestra los términos más frecuentes (y distintivos) de las entrevistas agrupadas.
# Sirve como apoyo para **codificar temas** en tu análisis cualitativo.

# %% [markdown]
# # 7. Interpretación cualitativa final
#
# | Cluster | Tema emergente                             | Palabras clave destacadas                          | Interpretación cualitativa                                                                 |
# | ------- | ------------------------------------------ | -------------------------------------------------- | ------------------------------------------------------------------------------------------ |
# | 0       | **Ansiedad ante la evaluación**            | nervioso, miedo, ansiedad, frustración             | Los estudiantes expresan emociones negativas y bloqueos ante la evaluación.                |
# | 1       | **Motivación y aprendizaje significativo** | motivación, práctico, proyectos, retroalimentación | Los estudiantes asocian emociones positivas cuando la evaluación tiene sentido y feedback. |

# %% [markdown]
# # 8. Reflexión metodológica

# %% [markdown]
# * Este tipo de análisis **no reemplaza** la interpretación humana, pero **ayuda a descubrir patrones** o temas dominantes en grandes volúmenes de texto.
# * En combinación con **análisis de contenido cualitativo**, **análisis de discurso** o **teoría fundamentada**, el TF-IDF puede apoyar la **triangulación** de categorías.
# * Documentar este proceso en Jupyter (y compartirlo en GitHub) favorece la **ciencia abierta y reproducible**.

# %% [markdown]
# # **Análisis de entrevistas cualitativas con TF-IDF y K-Means**

# %% [markdown]
# ## *Aplicación a la investigación educativa y emocional en estudiantes*

# %% [markdown]
# # **Propósito del cuaderno**
#
# Este cuaderno Jupyter tiene como propósito enseñar cómo aplicar técnicas de **procesamiento del lenguaje natural (NLP)** y **aprendizaje no supervisado** (clustering) al **análisis de entrevistas cualitativas**.

# %% [markdown]
# El caso de estudio se centra en las **emociones de los estudiantes frente a la evaluación**, conectando la mirada cualitativa interpretativa con herramientas cuantitativas de análisis textual, promoviendo una perspectiva **mixta y reproducible** de la investigación educativa.
#
# ---

# %% [markdown]
# # Introducción teórica

# %% [markdown]
# ## 1.1. El valor del análisis asistido por computadora en investigación cualitativa

# %% [markdown]
# En la investigación cualitativa tradicional, el análisis de entrevistas se basa en la **lectura interpretativa y la codificación temática**.
# Sin embargo, con herramientas de ciencia de datos, es posible **apoyar la identificación de patrones semánticos** mediante técnicas de procesamiento de texto, sin perder el carácter interpretativo.
#
# El uso de `TfidfVectorizer` permite **cuantificar el lenguaje** sin descontextualizarlo, sirviendo como una lente para descubrir temas emergentes.
#
# ---

# %% [markdown]
# # 1.2. Fundamento matemático del modelo TF-IDF
#
# El vectorizador **TF-IDF (Term Frequency – Inverse Document Frequency)** transforma textos en números midiendo la **importancia relativa** de cada palabra en un conjunto de documentos.
#
# $$
# TFIDF(t, d) = TF(t, d) \times IDF(t)
# $$
#
# Donde:
#
# $$
# TF(t, d) = \frac{\text{Número de veces que aparece el término } t \text{ en el documento } d}{\text{Número total de términos en } d}
# $$

# %% [markdown]
# $$
# IDF(t) = \log\left(\frac{N}{1 + n_t}\right)
# $$
#
# * $t$: término o palabra
# * $d$: documento (entrevista)
# * $N$: número total de documentos
# * $n_t$: número de documentos donde aparece el término $t$

# %% [markdown]
# El resultado es un valor alto cuando la palabra es **frecuente en un documento pero rara en el resto**, lo que indica **especificidad temática**.
#
# ---

# %% [markdown]
# # Aplicación práctica en Python
#
# ## 2.1. Importar librerías

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np

# %% [markdown]
# ## 2.2. Corpus de entrevistas simuladas

# %%
# Corpus representativo de entrevistas sobre emociones en la evaluación
entrevistas = [
    "Me siento muy nervioso antes de los exámenes, temo no recordar lo que estudié.",
    "Cuando el profesor explica bien, me siento más tranquilo durante la evaluación.",
    "La ansiedad me bloquea y no puedo concentrarme al responder.",
    "Siento motivación cuando los exámenes son prácticos y relacionados con la vida real.",
    "Me frustra cuando no entiendo lo que me preguntan en el examen.",
    "Disfruto los exámenes cuando puedo aplicar lo aprendido en proyectos.",
    "Tengo miedo a equivocarme y que el profesor piense que no estudié.",
    "Me gusta cuando el profesor nos da retroalimentación después de la prueba.",
    "Pierdo el interés cuando las evaluaciones son solo de memoria.",
    "Me siento más confiado cuando estudio con mis compañeros."
]

df = pd.DataFrame({"Entrevista": entrevistas})
df
# Out:
#                                           Entrevista
# 0  Me siento muy nervioso antes de los exámenes, ...
# 1  Cuando el profesor explica bien, me siento más...
# 2  La ansiedad me bloquea y no puedo concentrarme...
# 3  Siento motivación cuando los exámenes son prác...
# 4  Me frustra cuando no entiendo lo que me pregun...
# 5  Disfruto los exámenes cuando puedo aplicar lo ...
# 6  Tengo miedo a equivocarme y que el profesor pi...
# 7  Me gusta cuando el profesor nos da retroalimen...
# 8  Pierdo el interés cuando las evaluaciones son ...
# 9  Me siento más confiado cuando estudio con mis ...

# %% [markdown]
# # 2.3. Representación TF-IDF

# %%
vectorizer = TfidfVectorizer(stop_words='spanish')
X = vectorizer.fit_transform(df["Entrevista"])

# Mostrar matriz TF-IDF
tfidf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
tfidf_df.head()

# %% [markdown]
# **Interpretación:**
# Cada valor refleja la **relevancia** de una palabra en una entrevista.
# Palabras comunes (como “profesor” o “evaluación”) pueden tener valores bajos si aparecen en muchos discursos, mientras que palabras distintivas (como “nervioso” o “proyectos”) tendrán valores altos.

# %% [markdown]
# # 2.4. Agrupación semántica con K-Means

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
df["Cluster"] = kmeans.fit_predict(X)
df

# %% [markdown]
# **Análisis inicial:**
#
# * `Cluster 0`: puede agrupar discursos con **ansiedad, miedo y nerviosismo**.
# * `Cluster 1`: puede agrupar discursos con **motivación, confianza y disfrute**.

# %% [markdown]
# # 2.5. Palabras más representativas por grupo

# %%
palabras = vectorizer.get_feature_names_out()
clusters = kmeans.labels_

mean_tfidf = X.toarray().T.dot(pd.get_dummies(clusters)) / np.bincount(clusters)

for i in range(kmeans.n_clusters):
    top_idx = mean_tfidf[:, i].argsort()[::-1][:10]
    top_words = [palabras[j] for j in top_idx]
    print(f"\n Cluster {i} - Palabras clave:")
    print(", ".join(top_words))

# %% [markdown]
# # 2.6. Visualización con nubes de palabras

# %%
for i in range(kmeans.n_clusters):
    texto_cluster = " ".join(df[df["Cluster"] == i]["Entrevista"])
    nube = WordCloud(width=800, height=400, background_color='white', colormap='plasma').generate(texto_cluster)
    plt.figure(figsize=(8,4))
    plt.imshow(nube, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"Nube de palabras - Cluster {i}")
    plt.savefig(r"C:\Users\marco\Downloads\nube_de_palabras_cluster.png")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\marco\Documentos\investigacion\linea_invest_didact_math_data\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Entrevista'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # Interpretación cualitativa y triangulación
#
# | **Cluster** | **Tema emergente**                       | **Palabras clave**                                  | **Interpretación cualitativa**                                                      |
# | ----------- | ---------------------------------------- | --------------------------------------------------- | ----------------------------------------------------------------------------------- |
# | 0           | Ansiedad y temor ante la evaluación      | nervioso, miedo, ansiedad, frustración              | Emociones negativas relacionadas con el miedo al error y la autoeficacia.           |
# | 1           | Motivación y confianza en el aprendizaje | motivación, proyectos, retroalimentación, confianza | Emociones positivas vinculadas al acompañamiento docente y sentido del aprendizaje. |

# %% [markdown]
# # Reflexión teórica y metodológica

# %% [markdown]
# 1. **Triangulación cuali–cuanti:**
#    Los algoritmos no sustituyen la interpretación, sino que **ayudan a descubrir temas dominantes** y a sustentar cuantitativamente la codificación cualitativa.

# %% [markdown]
# 2. **Interpretación situada:**
#    Las palabras deben analizarse **en su contexto discursivo**, considerando la intención del hablante y la situación educativa.

# %% [markdown]
# 3. **Reproducibilidad:**
#    Al documentar todo el proceso en Python, se favorece la **transparencia científica** y la replicabilidad de los hallazgos, siguiendo los principios de **ciencia abierta**.

# %% [markdown]
# 4. **Aplicación pedagógica:**
#    Este ejercicio puede utilizarse en cursos de:
#
#    * *Metodología de la investigación educativa*
#    * *Ciencia de datos aplicada a las ciencias sociales*
#    * *Psicología educativa*
#    * *Administración de empresas (gestión del talento humano y clima organizacional)*

# %% [markdown]
# # Actividades propuestas para estudiantes
#
# | Tipo de actividad   | Descripción                                                                  | Herramienta       | Producto esperado                             |
# | ------------------- | ---------------------------------------------------------------------------- | ----------------- | --------------------------------------------- |
# | **Lectura crítica** | Interpretar los resultados de clustering y proponer categorías cualitativas. | Python + Jupyter  | Informe de interpretación.                    |
# | **Experimentación** | Cambiar el número de clusters y observar variaciones semánticas.             | `KMeans`          | Reflexión escrita sobre los temas emergentes. |
# | **Extensión**       | Aplicar el análisis a entrevistas reales de una investigación educativa.     | `TfidfVectorizer` | Cuaderno Jupyter + video de presentación.     |
#
# ---

# %% [markdown]
# # Autoevaluación
#
# Reflexiona sobre tu aprendizaje:
#
# 1. ¿Qué aporta el análisis TF-IDF al estudio cualitativo del lenguaje?
# 2. ¿Cómo puede el clustering apoyar la codificación temática de entrevistas?
# 3. ¿Qué precauciones éticas y metodológicas deben tenerse al automatizar el análisis del discurso?

# %% [markdown]
# # Apéndice sobre kmeans

# %% [markdown]
# Este fragmento de código aplica **K-means clustering** para **agrupar respuestas de texto** (por ejemplo, de entrevistas, cuestionarios o encuestas) de acuerdo con su **similitud semántica**, medida a través de **vectores TF-IDF**.

# %% [markdown]
# Vamos a desglosar el proceso paso a paso:
#
# ---

# %% [markdown]
# ### 🧩 1. Importación de librerías

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %% [markdown]
# * **`TfidfVectorizer`** convierte el texto en una **matriz numérica** donde cada columna representa una palabra y cada fila un documento (en este caso, una respuesta).
#
#   * TF-IDF significa *Term Frequency – Inverse Document Frequency*.
#   * Evalúa qué tan importante es una palabra dentro de un documento respecto al conjunto total de documentos.
# * **`KMeans`** es un algoritmo de aprendizaje no supervisado que **agrupa automáticamente datos en K grupos (clusters)**.
#
# ---

# %% [markdown]
# # 2. Representación vectorial del texto

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["Respuesta_limpia"])

# %% [markdown]
# * Aquí, `df["Respuesta_limpia"]` contiene el texto procesado (sin stopwords, minúsculas, sin puntuación, etc.).
# * `fit_transform()`:
#
#   * **fit:** aprende el vocabulario (las palabras únicas).
#   * **transform:** convierte cada respuesta en un **vector TF-IDF**.
# * El resultado, `X`, es una **matriz dispersa** de tamaño `(n_respuestas, n_palabras)`.
#
# *Cada respuesta se convierte en un punto en un espacio de alta dimensión, donde las coordenadas reflejan la importancia de las palabras.*
#
# ---

# %% [markdown]
# # 3. Creación del modelo K-means

# %%
kmeans = KMeans(n_clusters=2, random_state=42)

# %% [markdown]
# * Se crea un modelo K-means con **2 clusters**.
# * `random_state=42` asegura reproducibilidad.
# * El algoritmo K-means intentará **dividir los datos en 2 grupos** según la similitud entre los vectores TF-IDF.
#
# ---

# %% [markdown]
# ## 4. Entrenamiento del modelo

# %%
kmeans.fit(X)

# %% [markdown]
# Aquí ocurre el proceso de **clustering**, que sigue estos pasos:
#
# 1. **Inicialización**: elige aleatoriamente 2 centroides (uno para cada cluster).
# 2. **Asignación**: cada respuesta se asigna al cluster cuyo centroide esté más cercano (según la distancia euclidiana en el espacio TF-IDF).
# 3. **Actualización**: se recalculan los centroides como el promedio de los puntos de cada cluster.
# 4. **Iteración**: se repiten los pasos 2 y 3 hasta que las asignaciones ya no cambian significativamente o se alcanza el número máximo de iteraciones.

# %% [markdown]
# El objetivo del algoritmo es **minimizar la suma de distancias cuadradas** de cada punto a su centroide:
# $$
# \text{Inertia} = \sum_{i=1}^{n} \min_{j} ||x_i - \mu_j||^2
# $$
# donde $\mu_j$ es el centroide del cluster ( j ).
#
# ---

# %% [markdown]
# ### 🧾 5. Asignación de etiquetas a cada texto
#
# ```python
# df["Cluster"] = kmeans.labels_
# ```
#
# * `kmeans.labels_` contiene un número entero (0 o 1 en este caso) indicando a qué grupo pertenece cada respuesta.
# * Se agrega una nueva columna `Cluster` al DataFrame `df` para identificar a qué grupo pertenece cada respuesta textual.
#
# ---

# %% [markdown]
# # 6. Resultado

# %%
df

# %% [markdown]
# * Muestra el DataFrame original con la nueva columna “Cluster”.
# * Puedes analizar qué tipo de respuestas quedaron agrupadas juntas, revisando, por ejemplo:

# %%
df.groupby("Cluster")["Respuesta_limpia"].apply(list)

# %% [markdown]
#   Esto te permitirá **interpretar los temas o patrones semánticos** que emergen en cada grupo.
#
# ---

# %% [markdown]
# ### 🌱 En resumen
#
# | Etapa | Acción                    | Herramienta                          |
# | ----- | ------------------------- | ------------------------------------ |
# | 1     | Limpieza del texto        | (antes del código)                   |
# | 2     | Vectorización TF-IDF      | `TfidfVectorizer`                    |
# | 3     | Clustering no supervisado | `KMeans`                             |
# | 4     | Etiquetado de clusters    | `kmeans.labels_`                     |
# | 5     | Interpretación de temas   | agrupando y leyendo textos similares |

# %% [markdown]
# Vamos a añadir una **visualización clara y didáctica** de los *clusters semánticos* detectados por K-means, reduciendo la dimensionalidad del espacio TF-IDF a **2 dimensiones** con **PCA** (Análisis de Componentes Principales).

# %% [markdown]
# Esto te permitirá ver, de forma aproximada, cómo el algoritmo agrupa las respuestas similares.
#
# ---

# %% [markdown]
# ## 🧠 Código completo con visualización

# %% [markdown]
# ```python
# # ================================================
# # 📚 Análisis de clusters en texto con TF-IDF y KMeans
# # ================================================
#
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.cluster import KMeans
# from sklearn.decomposition import PCA
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Supongamos que tienes tu DataFrame df con una columna 'Respuesta_limpia'
# # Ejemplo mínimo:
# # df = pd.DataFrame({
# #     "Respuesta_limpia": [
# #         "me gusta aprender con ejemplos",
# #         "prefiero clases teóricas",
# #         "las prácticas ayudan a entender",
# #         "la teoría es fundamental para comprender",
# #         "aprendo mejor haciendo ejercicios"
# #     ]
# # })
#
# # 1️⃣ Vectorización TF-IDF
# vectorizer = TfidfVectorizer()
# X = vectorizer.fit_transform(df["Respuesta_limpia"])
#
# # 2️⃣ Aplicar K-means con 2 clusters
# kmeans = KMeans(n_clusters=2, random_state=42)
# kmeans.fit(X)
# df["Cluster"] = kmeans.labels_
#
# # 3️⃣ Reducir dimensiones a 2 componentes para visualización
# pca = PCA(n_components=2, random_state=42)
# X_pca = pca.fit_transform(X.toarray())
#
# # 4️⃣ Crear DataFrame con componentes principales
# df_pca = pd.DataFrame({
#     "PC1": X_pca[:, 0],
#     "PC2": X_pca[:, 1],
#     "Cluster": df["Cluster"]
# })
#
# # 5️⃣ Visualización de los clusters
# plt.figure(figsize=(8, 6))
# for cluster in df_pca["Cluster"].unique():
#     subset = df_pca[df_pca["Cluster"] == cluster]
#     plt.scatter(subset["PC1"], subset["PC2"], label=f"Cluster {cluster}", s=80, alpha=0.7)
#
# plt.title("Visualización de clusters de respuestas (PCA + K-means)", fontsize=14)
# plt.xlabel("Componente principal 1")
# plt.ylabel("Componente principal 2")
# plt.legend()
# plt.grid(True, linestyle="--", alpha=0.5)
# plt.show()
#
# # 6️⃣ Visualizar los textos por cluster (para interpretación)
# for c in sorted(df["Cluster"].unique()):
#     print(f"\n🔹 Cluster {c}:")
#     for r in df[df["Cluster"] == c]["Respuesta_limpia"]:
#         print("  -", r)
# ```
#
# ---

# %% [markdown]
# ## 🔍 Interpretación de la gráfica
#
# * Cada punto representa una **respuesta**.
# * Los colores muestran los **grupos semánticos** detectados.
# * Si los puntos de un color están cercanos entre sí y alejados de los otros, significa que **K-means ha identificado temas distintos**.
#
# Por ejemplo:
#
# * Un grupo podría corresponder a respuestas más **prácticas o aplicadas** (“me gusta aprender haciendo”).
# * Otro grupo podría reflejar respuestas más **teóricas o reflexivas** (“la teoría es fundamental”).
#
# ---
#
# ## ✨ Sugerencia didáctica
#
# Puedes invitar a tus estudiantes o participantes de investigación a:
#
# 1. **Leer las respuestas de cada cluster.**
# 2. **Ponerle un nombre al grupo** (por ejemplo, *“aprendizaje práctico”* vs *“aprendizaje teórico”*).
# 3. **Reflexionar sobre las similitudes semánticas** que el algoritmo detecta sin intervención humana.
#
# ---
#
# ¿Quieres que te prepare una **versión interactiva con Plotly e ipywidgets**, donde se pueda explorar cada cluster dinámicamente (por ejemplo, seleccionar el número de clusters o leer las respuestas al pasar el cursor)?
# Sería ideal para presentarlo en clase o en un análisis de entrevistas.

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.
