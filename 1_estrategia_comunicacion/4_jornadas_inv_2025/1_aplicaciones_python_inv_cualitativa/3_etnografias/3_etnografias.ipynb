# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/tools_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/tools_numpy.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
import qrcode
from IPython.display import display

def generar_qr_notebook(url):
    """
    Genera un código QR para una URL y lo muestra en un cuaderno Jupyter.
    
    Parámetros:
    url (str): La URL para la cual se generará el código QR.
    
    Retorna:
    None (pero muestra el código QR en el notebook)
    """
    # Crear el objeto QR
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )
    
    # Añadir la URL al código QR
    qr.add_data(url)
    qr.make(fit=True)
    
    # Crear la imagen del QR
    img = qr.make_image(fill_color="black", back_color="white")
    
    # Mostrar la imagen en el notebook
    display(img)

# %%
url = ''
generar_qr_notebook(url)

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso:  ]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = ''>

# %% [markdown]
# Reconocimiento a las profesoras destacadas en enseñanza de la matemática en Colombia

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/g_lideres.xlsx'
df = pd.read_excel(path)
df.head()
# Out:
# Empty DataFrame
# Columns: [Nombre]
# Index: []

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# ## Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 200>

# %% [markdown]
# # Metodología Aprendizaje Basado en Problemas y Proyectos (ABPP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 200>

# %% [markdown]
# # Desarrollo del pensamiento computacional con Lenguajes Python, R; y con archivos R Markdown orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 200>

# %% [markdown]
# # Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 200>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# # Y el enfoque de Teoría de Registros de Representación Semiótica (TRRS) de la matemática de Duval

# %% [markdown]
# # Prompt
#
# Dame el diseño de un taller práctico o Master Class sobre "Herramientas de Python para investigación cualitativa en Administración de empresas: Caso Etnografías". Agrégale ejemplos sencillos de aplicación para Investigación en el programa de Administración de Empresas de la Facultad de Ciencias Económicas.  Y que este diseño sea para implementar esta clase a través de cuadernos Jupyter editados en Google Colab o en VS Code.

# %% [markdown]
# Perfecto, Marco 🙌. Aquí tienes un **diseño completo de un Taller/Master Class** sobre *Herramientas de Python para investigación cualitativa en Administración de Empresas: Caso Etnografías*, pensado para implementación práctica con cuadernos Jupyter (Google Colab o VS Code).
#
# ---
#
# # 🏛️ Master Class: Herramientas de Python para Investigación Cualitativa
#
# ## Caso de Estudio: **Etnografías en Administración de Empresas**
#
# ---
#
# ## 🎯 **Objetivos del Taller**
#
# * Introducir a los estudiantes en el uso de Python como apoyo para analizar datos textuales de etnografías en investigación empresarial.
# * Mostrar cómo organizar, limpiar y explorar datos de observaciones de campo y notas etnográficas.
# * Aplicar técnicas básicas de análisis de texto (palabras clave, nubes de palabras, clustering) para apoyar la interpretación cualitativa.
# * Relacionar hallazgos etnográficos con problemáticas en el programa de Administración de Empresas.
#
# ---
#
# ## 📚 **Estructura del Taller**
#
# ### **1. Introducción**
#
# * ¿Qué es la investigación etnográfica?
# * Ejemplo en Administración de Empresas: observación participante en un **equipo de ventas** o en una **práctica de gestión de proyectos**.
# * Limitaciones y ventajas de usar Python en apoyo al análisis de campo.
#
# ---
#
# ### **2. Preparación del entorno**
#
# * Ejecución en **Google Colab** o **VS Code**.
# * Instalación de librerías:
#
# ```python
# !pip install pandas numpy nltk wordcloud scikit-learn matplotlib
# ```
#
# ---
#
# ### **3. Construcción del dataset etnográfico**
#
# Ejemplo sencillo: notas de campo tomadas en observación de un **departamento de mercadeo**.
#
# ```python
# import pandas as pd
#
# data = {
#     "Observacion": [
#         "Durante la reunión semanal, se observó poca participación de los nuevos integrantes.",
#         "Los empleados expresaron frustración por la falta de claridad en los objetivos.",
#         "Se evidenció un fuerte liderazgo informal por parte de un asistente administrativo.",
#         "La comunicación entre áreas de mercadeo y ventas parece limitada."
#     ]
# }
#
# df = pd.DataFrame(data)
# df
# ```
#
# ---
#
# ### **4. Limpieza y preprocesamiento del texto**
#
# ```python
# import nltk, re
# from nltk.corpus import stopwords
#
# nltk.download("stopwords")
# stop_words = set(stopwords.words("spanish"))
#
# def limpiar_texto(texto):
#     texto = texto.lower()
#     texto = re.sub(r"[^a-záéíóúñ\s]", "", texto)
#     palabras = [p for p in texto.split() if p not in stop_words]
#     return " ".join(palabras)
#
# df["Obs_limpia"] = df["Observacion"].apply(limpiar_texto)
# df
# ```
#
# ---
#
# ### **5. Análisis exploratorio**
#
# #### a) Frecuencia de palabras
#
# ```python
# from collections import Counter
#
# palabras = " ".join(df["Obs_limpia"]).split()
# conteo = Counter(palabras)
# conteo.most_common(8)
# ```
#
# #### b) Visualización con nube de palabras
#
# ```python
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt
#
# texto = " ".join(df["Obs_limpia"])
# wc = WordCloud(width=600, height=400, background_color="white").generate(texto)
#
# plt.imshow(wc, interpolation="bilinear")
# plt.axis("off")
# plt.show()
# ```
#
# ---
#
# ### **6. Identificación de patrones (TF-IDF + clustering simple)**
#
# ```python
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.cluster import KMeans
#
# vectorizer = TfidfVectorizer()
# X = vectorizer.fit_transform(df["Obs_limpia"])
#
# kmeans = KMeans(n_clusters=2, random_state=42)
# df["Cluster"] = kmeans.fit_predict(X)
# df
# ```
#
# ---
#
# ### **7. Interpretación cualitativa**
#
# * **Cluster 0**: notas sobre **liderazgo y comunicación**.
# * **Cluster 1**: notas sobre **participación y frustración**.
#
# 👉 Discusión: ¿cómo se relacionan estos patrones con la cultura organizacional de un área administrativa?
#
# ---
#
# ## 📝 **Ejemplo de aplicación en Administración de Empresas**
#
# * **Etnografía en la Facultad**: observación de estudiantes en prácticas empresariales.
# * Python ayuda a:
#
#   * Identificar temas recurrentes en notas de campo.
#   * Comparar percepciones entre distintos actores (empleados, directivos, estudiantes en práctica).
#   * Apoyar la triangulación de información entre observación, entrevistas y documentos.
#
# ---
#
# ## 🎤 **Actividad práctica**
#
# 1. Los estudiantes crean un archivo `.csv` con **notas etnográficas simuladas** (ej. observaciones de reuniones, dinámicas de equipo, comunicación interna).
# 2. Aplican el flujo: limpieza → análisis de palabras → nube de palabras → clustering.
# 3. Presentan un **informe corto** interpretando los resultados y conectándolos con problemáticas empresariales (ej. liderazgo, clima organizacional, gestión del tiempo).
#
# ---
#
# ## 📌 **Cierre**
#
# * Python no sustituye la riqueza interpretativa de la etnografía, pero permite **organizar, visualizar y detectar patrones** en grandes volúmenes de notas.
# * En el contexto de Administración de Empresas, esto facilita **detectar tensiones, dinámicas de poder y problemas de comunicación**.
# * Se fomenta en los estudiantes la integración de competencias digitales con el análisis crítico cualitativo.
#
# ---
#
# ¿Quieres que te prepare también el **cuaderno Jupyter (.ipynb) ya estructurado con este diseño** para que lo uses directamente en Colab o VS Code con tus estudiantes?

# %% [markdown]
# ### **Etnografías y Python en la Investigación Cualitativa en el Bajo Cauca Antioqueño**

# %% [markdown]
# La **etnografía** es una metodología clave en la investigación cualitativa, especialmente en contextos como el **Bajo Cauca Antioqueño**, donde las dinámicas sociales, económicas y ambientales son complejas. Python, como lenguaje de programación, puede potenciar el análisis etnográfico mediante:

# %% [markdown]
# 1. **Sistematización de datos cualitativos**:
#    - Automatización de transcripciones de entrevistas (con librerías como `speech_recognition` o `transformers`).
#    - Organización de notas de campo, diarios etnográficos y registros audiovisuales en bases de datos estructuradas (JSON, CSV, SQLite).

# %% [markdown]
# 2. **Análisis de contenido y discurso**:
#    - Procesamiento de lenguaje natural (NLP) para identificar patrones temáticos en entrevistas (`NLTK`, `spaCy`).
#    - Codificación automatizada de categorías emergentes en narrativas comunitarias.

# %% [markdown]
# 3. **Visualización de redes sociales y mapeo comunitario**:
#    - Uso de `NetworkX` o `Gephi` (con Python) para analizar relaciones entre actores sociales.
#    - Georreferenciación de datos etnográficos con `folium` o `geopandas`.

# %% [markdown]
# 4. **Triangulación con datos cuantitativos**:
#    - Integración de estadísticas socioeconómicas (ej. minería, cultivos) con relatos etnográficos (`pandas`, `matplotlib`).

# %% [markdown]
# #### **Aportes a la Sostenibilidad en el Bajo Cauca**
# - **Identificación de conflictos socioambientales**: Análisis de narrativas sobre minería, deforestación o agua.
# - **Mapeo de iniciativas comunitarias sostenibles**: Sistematización de proyectos locales (agroecología, turismo comunitario).
# - **Evaluación de políticas públicas**: Cruce de datos etnográficos con indicadores de desarrollo sostenible.

# %% [markdown]
# ---
#
# ### **Diseño de Práctica: Uso de Python en Etnografías**
# **Objetivo**: Enseñar a investigadores sociales a aplicar Python en el procesamiento de datos etnográficos del Bajo Cauca.

# %% [markdown]
# #### **1. Contextualización (30 min)**
# - Presentación del Bajo Cauca: problemáticas socioambientales y relevancia de la etnografía.
# - Caso de estudio: **"Memorias comunitarias sobre el conflicto y la sostenibilidad"** (ejemplo real o simulado).

# %% [markdown]
# #### **2. Taller Práctico (2 horas)**
# **Herramientas**: Jupyter Notebook, Python 3.8+, librerías `pandas`, `NLTK`, `matplotlib`.

# %% [markdown]
# ##### **Actividad 1: Organización de datos etnográficos**
# - Crear un archivo JSON/CSV con datos simulados de entrevistas:

# %%
import pandas as pd
  
datos_etnograficos = [
      {"id": 1, "municipio": "Caucasia", "entrevistado": "Líder comunitario", "texto": "El río ya no da lo mismo...", "tema": "agua"},
      {"id": 2, "municipio": "El Bagre", "entrevistado": "Agricultor", "texto": "Los cultivos de coca dejaron tierras inservibles...", "tema": "tierra"},
  ]
  
df = pd.DataFrame(datos_etnograficos)
df.to_csv("entrevistas_bajo_cauca.csv", index=False)

# %% [markdown]
# ##### **Actividad 2: Análisis de contenido básico**
# - Contar frecuencia de palabras clave con `NLTK`:
#   ```python
#   from nltk.tokenize import word_tokenize
#   from collections import Counter
#
#   texto = " ".join(df["texto"].tolist())
#   palabras = word_tokenize(texto.lower(), language="spanish")
#   filtradas = [p for p in palabras if len(p) > 4 and p.isalpha()]  # Eliminar palabras cortas
#   Counter(filtradas).most_common(5)  # Top 5 palabras recurrentes
#   ```
#
# ##### **Actividad 3: Visualización de temas**
# - Gráfico de barras con temas predominantes:
#   ```python
#   df["tema"].value_counts().plot(kind="bar", color="green")
#   plt.title("Temas más abordados en entrevistas")
#   plt.xlabel("Tema")
#   plt.ylabel("Frecuencia")
#   ```
#
# #### **3. Discusión y aplicación (30 min)**
# - ¿Cómo estos métodos complementan la interpretación etnográfica tradicional?
# - Ejercicio propuesto:
#   - Georreferenciar conflictos mencionados usando coordenadas ficticias.
#   - Triangulación con datos oficiales (ej. mapas de minería ilegal).
#
# ---

# %% [markdown]
# ### **Recursos Adicionales**
# - **Dataset de ejemplo**: [EMBRAPA](https://www.embrapa.br) (para cruzar datos agropecuarios).
# - **Librerías útiles**:
#   - `textract`: Extraer texto de audios o PDFs de entrevistas.
#   - `pyarrow`: Manejar datos grandes (ej. años de diarios de campo).
#
# Esta práctica integra metodologías cualitativas con técnicas computacionales, ofreciendo una **mirada innovadora** para investigaciones en territorios complejos como el Bajo Cauca.

# %% [markdown]
# # ARTÍCULO 1. Definir el calendario académico para los diferentes programas de pregrado de los campus
# regionalizados, correspondiente al primer periodo académico del año 2025, así:
# * Oferta 28 de enero de 2025
# * Matrícula 30 de enero de 2025
# * Ajustes 03 al 10 de febrero de 2025
# * Inicio de clases 10 de febrero de 2025
# * Límite evaluación del 40% 06 de abril de 2025
# * Terminación de clases 08 de junio de 2025
# * Exámenes finales 09 al 15 de junio de 2025
# * Habilitación y validación 16 al 22 de junio de 2025
# * Terminación oficial 23 de junio de 2025

# %% [markdown]
# # Componente de manejo de calculadora Casio asociado al objetivo de aprendizaje de esta clase
#
# ## Pasos para lograr el objetivo de aprendizaje con la experimentación en la calculadora Casio 991LA cw

# %% [markdown]
# # Cursos que orienta el profesor Marco Julio Cañas Campillo en 2025
#
# 1. Práctica Pedagógica V para Licenciatura en Educación Infantil
# 2. Fundamentos de Lógica para Licenciatura en Matemáticas
# 3. Análisis Numérico para Licenciatura en Matemáticas.
# 4. Cálculo Vectorial para Ingeniería Agropecuaria

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12: Cálculo Vectorial
# * Martes 8-12 M: Fundamentos de Aritmética.
# * Miércoles 8 a 12 M: Fundamentos de la Lógica
# * Jueves 2 a 6 PM: Desarrollo del pensamiento matemático en la infancia.
# * Viernes 8 - 12 M: Desarrollo del pensamiento matemático en la infancia.
# * Sábados 8-12 Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.

# %% [markdown]
# # Horarios de monitoría y asesoría
#
# Coordinador de los cursos de la Facultad de Educación para regiones:
#
# Andrés Vélez: regioneducacion.fedu@udea.edu.co
# Coordinador Regiones
# Facultad de Educación
# Universidad de Antioquia

# %% [markdown]
# ## Monitor Manuel San Juan Serrano
#
# Contactar escribiendo al correo: manuel.serrano1@udea.edu.co

# %% [markdown]
# Martes y jueves de 8 - 12
# Miércoles 10 - 12 y de 2 a 4 PM
# Sábado: 8 - 12

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Lorena Barba. Enseñanza y Aprendizaje con Jupyter](https://jupyter4edu.github.io/jupyter-edu-book/)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)
#
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
#
#
#
#
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Apéndice sobre calendarios y coordinaciones
#
# A continuación le envío el horario de la asignatura Cálculo Vectorial
#
# Días:
# Lunes - Hora: 7:00 a 12:00M
# Fechas:
# Febrero: 10-17-24
#  Marzo: 3-10-17-31
# Abril:7-21-28
# Mayo:5-12-19
#
# Agradezco su apoyo, y si presenta alguna dificultad puede contactarme.
#
# Cordialmente,
# Juan Felipe Rivera Hernández
# Contacto: 3106314300
