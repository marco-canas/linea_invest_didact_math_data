# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/linea_invest_didact_math_data/blob/main/1_estrategia_comunicacion/4_jornadas_inv_2025/tools_inv_cuatitativa_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/linea_invest_didact_math_data/blob/main/1_estrategia_comunicacion/4_jornadas_inv_2025/tools_inv_cuatitativa_python.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # Código completo para generar un QR en Jupyter Notebook

# %%
# QR para la masterclass
import qrcode
from IPython.display import display

url = "https://colab.research.google.com/github/marco-canas/linea_invest_didact_math_data/blob/main/1_estrategia_comunicacion/4_jornadas_inv_2025/tools_inv_cuatitativa_python.ipynb"

# Configurar el QR code
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
)

# Añadir la URL al QR
qr.add_data(url)
qr.make(fit=True)

# Crear la imagen del QR
img = qr.make_image(fill_color="black", back_color="white")

# Mostrar el QR en el notebook
display(img)

# Opcional: Mostrar también la URL como texto
print("\nURL codificada en el QR:")
print(url)
# Out:
# URL codificada en el QR:
# https://colab.research.google.com/github/marco-canas/linea_invest_didact_math_data/blob/main/1_estrategia_comunicacion/4_jornadas_inv_2025/tools_inv_cuatitativa_python.ipynb

# %% [markdown]
# ## Instrucciones para usar el código:
#
# 1. **Requisitos previos**:
#    - Necesitas tener instaladas las bibliotecas `qrcode` y `IPython`. Puedes instalarlas con:
#      ```
#      pip install qrcode ipython
#      ```

# %% [markdown]
# 2. **Cómo usar**:
#    - Copia este código completo en una celda de tu Jupyter Notebook
#    - Ejecuta la celda para generar y mostrar el código QR

# %% [markdown]
# 3. **Personalización**:
#    - Puedes cambiar el tamaño del QR modificando el parámetro `box_size`
#    - Puedes cambiar los colores modificando `fill_color` y `back_color`
#    - Para hacer el borde más grueso, aumenta el valor de `border`

# %% [markdown]
# 4. **Funcionamiento**:
#    - El código generará un QR que al ser escaneado llevará directamente a la URL del notebook en Google Colab
#    - También mostrará la URL como texto por si alguien prefiere copiarla manualmente
#
# El código QR generado será perfectamente escaneable por cualquier lector de QR estándar desde un dispositivo móvil.

# %% [markdown]
# # **Master Class: Herramientas de Python para Investigación Cualitativa**

# %% [markdown]
# **Dirigido a:** Investigadores del Bajo Cauca Antioqueño (Universidad de Antioquia, Campus Caucasia)
# **Duración:** 2 horas (presencial o híbrida)
# **Nivel:** Básico a intermedio

# %% [markdown]
# ## **Objetivo General**

# %% [markdown]
# Capacitar a investigadores en el uso de herramientas de Python para el análisis y procesamiento de datos cualitativos, optimizando sus procesos de investigación en áreas como ciencias sociales, humanidades y estudios regionales.

# %% [markdown]
# ## **Estructura del Taller**

# %% [markdown]
# ### **1. Introducción (15 min)**
# - Presentación del taller y expectativas.

# %% [markdown]
#
# - Importancia de Python en investigación cualitativa.

# %% [markdown]
# - Casos de aplicación en estudios regionales (ej: análisis de discurso, entrevistas, etnografías).

# %% [markdown]
#
# - Instalación de entornos recomendados (Google Colab, Jupyter Notebook de Anaconda y Visual Studio Code (Vs Code)).

# %% [markdown]
# #### **Presentación del taller y expectativas (5 min)**

# %% [markdown]
# - **Bienvenida:** Saludo inicial,
# - presentación del facilitador Marco Julio Cañas Campillo.
#
#    - Licenciado en Matemáticas y Física de la Universidad de Antioquia,
#   - con experiencia en investigación cualitativa y programación en Python.
#   - Magister en Ciencias Matemáticas de la Universidad Nacional de Colombia (Sede Medellín)

# %% [markdown]
# # - objetivos de la sesión.

# %% [markdown]
# - **Dinámica rompehielos:** Pregunta rápida a los participantes:
#
#    *"¿Qué esperan aprender hoy sobre Python y su aplicación en investigación cualitativa?"* (Respuestas breves en chat o verbalmente).

# %% [markdown]
# - **Ruta del taller:** Explicación breve de los módulos y metodología (teoría + práctica).

# %% [markdown]
# ## **Importancia de Python en investigación cualitativa (10 min)**

# %% [markdown]
# - **Contexto global:**
#   - Cómo herramientas digitales están transformando la investigación social (ej: minería de textos, automatización de análisis).
#   - Ventajas de Python: **gratuito, flexible, con librerías especializadas** vs. software tradicional (NVivo, Atlas.ti).

# %% [markdown]
# - **Enfoque local:**
#   - Relevancia para el Bajo Cauca: *"¿Cómo puede ayudar Python a estudiar problemáticas como conflicto, minería o dinámicas culturales con datos cualitativos?"*.
#   - Ejemplo concreto: *"Automatizar el análisis de 100 entrevistas sobre desplazamiento en la región"*.

# %% [markdown]
# ## **Casos de aplicación en estudios regionales (10 min)**

# %% [markdown]
#
# - **Proyectos reales o simulados:**

# %% [markdown]
#
#   1. **Análisis de discurso:** Extraer patrones en declaraciones de líderes sociales o medios locales.

# %% [markdown]
#
#   2. **Etnografías digitales:** Procesar diarios de campo o notas de observación con NLP.

# %% [markdown]
#
#   3. **Entrevistas:** Codificación automática de temas recurrentes (ej: "violencia", "resistencia").

# %% [markdown]
#
# - **Demo rápida (opcional):** Mostrar un gráfico de *wordcloud* generado con datos de un taller comunitario en Caucasia.

# %% [markdown]
# #### **Instalación de entornos recomendados (5 min)**

# %% [markdown]
# - **Opciones accesibles:**
#   - **Google Colab** (recomendado para principiantes, sin instalación).

# %% [markdown]
#
#   - **Jupyter Notebook de Anaconda** (guía rápida de instalación con Anaconda).

# %% [markdown]
#
# - **Enlace a repositorio:** Compartir carpeta con:

# %% [markdown]
#   - Instrucciones paso a paso.
#   - Dataset de ejemplo (ej: transcripción de una entrevista ficticia sobre cultivos en el Bajo Cauca).

# %% [markdown]
#
#   - Cuaderno de Jupyter preconfigurado.

# %% [markdown]
# #### **Notas para el facilitador:**

# %% [markdown]
# - **Adaptar el lenguaje:** Evitar tecnicismos excesivos; vincular siempre los ejemplos al contexto local.

# %% [markdown]
#
# - **Inclusión:** Si hay participantes con cero experiencia en programación, recalcar que se partirá desde lo básico.

# %% [markdown]
# - **Interacción:** Preguntar *"¿Alguien ha usado antes Python para análisis social?"* para medir el nivel del grupo.

# %% [markdown]
# **Transición al siguiente módulo:**

# %% [markdown]
# *"Ahora que entendemos el 'por qué', pasemos al 'cómo'. Vamos a explorar las herramientas básicas de Python para manejar sus datos cualitativos."*

# %% [markdown]
# # **2. Fundamentos de Python para Investigación (1/2 hora)**

# %% [markdown]
# - Sintaxis básica (variables, listas, diccionarios).
# - Manejo de archivos (lectura/escritura de textos, CSV, JSON).

# %% [markdown]
# - Librerías clave:
#   - `Pandas` (estructuración de datos cualitativos).
#   - `NLTK`/`spaCy` (procesamiento de lenguaje natural).
#   - `Matplotlib`/`WordCloud` (visualización de datos textuales).

# %% [markdown]
# ### **2. Fundamentos de Python para Investigación (1/2 hora)**

# %% [markdown]
# **Enfoque:** Aplicación práctica en proyectos de sostenibilidad y desarrollo regional del Bajo Cauca.

# %% [markdown]
# #### **1. Sintaxis Básica (20 min)**
# **Objetivo:** Familiarizar a los investigadores con estructuras de datos útiles para análisis cualitativo.

# %% [markdown]
# - **Variables:**
#   - Ejemplo aplicado:

# %%
comunidad = "Bajo Cauca"  # Texto relevante a estudios regionales

# %%
num_entrevistas = 50      # Datos de trabajo de campo

# %% [markdown]
#
# - **Listas y diccionarios:**

# %% [markdown]
#
#   - **Listas:** Para almacenar respuestas de entrevistas o categorías temáticas.

# %%
temas_entrevistas = ["conflicto", "minería", "cultivos", "agua"]

# %%
temas_entrevistas

# %% [markdown]
#
#   - **Diccionarios:** Para codificar frecuencias o características de comunidades.

# %%
  

datos_comunidad = {"municipio": "Caucasia", "población": 300_000,\
    "enfoque_investigación": "sostenibilidad"}

# %%
datos_comunidad

# %% [markdown]
#
#   - *Ejercicio práctico:* Crear una lista con 3 problemáticas del Bajo Cauca y un diccionario con datos ficticios de un proyecto.

# %%
problematicas_bajo_cauca = ["desplazamiento forzado", "contaminación de ríos",\
    "acceso limitado a educación"]
problematicas_bajo_cauca

# %%
proyecto_ficticio = {
    "nombre": "Proyecto Agua Segura",
    "municipio": "El Bagre",
    "beneficiarios": 1200,
    "objetivo": "Mejorar el acceso a agua potable en comunidades rurales",
    "año_inicio": 2023
}
proyecto_ficticio

# %% [markdown]
# #### **2. Manejo de Archivos (15 min)**
# **Objetivo:** Leer y almacenar datos cualitativos (textos, encuestas, registros etnográficos).

# %% [markdown]
# - **Archivos de texto (.txt):**

# %%
# Crear archivo ficticio de entrevista
contenido_entrevista = """Entrevistador: ¿Cuáles son los principales problemas que enfrenta su comunidad?
Líder comunitario: La minería ilegal ha contaminado los ríos y ha generado desplazamiento forzado. 
Además, el acceso a educación es limitado y muchas familias dependen de los cultivos para sobrevivir.
Entrevistador: ¿Qué acciones han tomado para enfrentar estos desafíos?
Líder comunitario: Hemos organizado talleres sobre sostenibilidad y gestionado proyectos para mejorar el 
acceso a agua potable. Sin embargo, la violencia sigue siendo una preocupación constante.
"""

# %%
with open("entrevista_bajo_cauca.txt", "w", encoding="utf-8") as f:
    f.write(contenido_entrevista)

# %%
with open("entrevista_bajo_cauca.txt", "r", encoding="utf-8") as file:
    texto = file.read()  # Para análisis de discurso

# %%
print(texto)

# %% [markdown]
#
# - **CSV/Excel (datos estructurados):**
#   - Usando Pandas:

# %%
import pandas as pd

# %%
# Datos ficticios de encuestas sobre sostenibilidad en el Bajo Cauca
data = [
    {"municipio": "Caucasia", "proyecto": "Agua Segura", "beneficiarios": 1200, "tema": "agua", "año": 2023},
    {"municipio": "El Bagre", "proyecto": "Cultivos Sostenibles", "beneficiarios": 800, "tema": "cultivos", "año": 2022},
    {"municipio": "Nechí", "proyecto": "Educación Rural", "beneficiarios": 500, "tema": "educación", "año": 2023},
    {"municipio": "Tarazá", "proyecto": "Minería Responsable", "beneficiarios": 950, "tema": "minería", "año": 2021},
    {"municipio": "Zaragoza", "proyecto": "Talleres Ambientales", "beneficiarios": 600, "tema": "medio ambiente", "año": 2022}
]

# %%
df = pd.DataFrame(data)
df

# %%
df.to_csv("encuestas_sostenibilidad.csv", index=False, encoding="utf-8")

# %%
import pandas as pd
datos = pd.read_csv("encuestas_sostenibilidad.csv")  # Ejemplo: datos de proyectos agropecuarios
datos

# %% [markdown]
# # Ahora el tipo de archivo excel
# 1. Crear el archivo excel a partir de una lista de diccionarios.
# 2. Leer el archivo Excel y mostrar su contenido.

# %%
# Datos ficticios de encuestas sobre sostenibilidad en el Bajo Cauca
data = [
    {"municipio": "Caucasia", "proyecto": "Agua Segura", "beneficiarios": 1200, "tema": "agua", "año": 2023},
    {"municipio": "El Bagre", "proyecto": "Cultivos Sostenibles", "beneficiarios": 800, "tema": "cultivos", "año": 2022},
    {"municipio": "Nechí", "proyecto": "Educación Rural", "beneficiarios": 500, "tema": "educación", "año": 2023},
    {"municipio": "Tarazá", "proyecto": "Minería Responsable", "beneficiarios": 950, "tema": "minería", "año": 2021},
    {"municipio": "Zaragoza", "proyecto": "Talleres Ambientales", "beneficiarios": 600, "tema": "medio ambiente", "año": 2022}
]

# %%
import pandas as pd

# %%
# Datos ficticios de encuestas sobre sostenibilidad en el Bajo Cauca
data = [
    {"municipio": "Caucasia", "proyecto": "Agua Segura", "beneficiarios": 1200, "tema": "agua", "año": 2023},
    {"municipio": "El Bagre", "proyecto": "Cultivos Sostenibles", "beneficiarios": 800, "tema": "cultivos", "año": 2022},
    {"municipio": "Nechí", "proyecto": "Educación Rural", "beneficiarios": 500, "tema": "educación", "año": 2023},
    {"municipio": "Tarazá", "proyecto": "Minería Responsable", "beneficiarios": 950, "tema": "minería", "año": 2021},
    {"municipio": "Zaragoza", "proyecto": "Talleres Ambientales", "beneficiarios": 600, "tema": "medio ambiente", "año": 2022}
]

# %%
# 1. Convertir a DataFrame y guardar como Excel
df = pd.DataFrame(data)
df
# Out:
#   municipio              proyecto  beneficiarios            tema   año
# 0  Caucasia           Agua Segura           1200            agua  2023
# 1  El Bagre  Cultivos Sostenibles            800        cultivos  2022
# 2     Nechí       Educación Rural            500       educación  2023
# 3    Tarazá   Minería Responsable            950         minería  2021
# 4  Zaragoza  Talleres Ambientales            600  medio ambiente  2022

# %%
nombre_archivo = "sostenibilidad_bajo_cauca.xlsx"
df.to_excel(nombre_archivo, index=False, sheet_name="Encuestas")
print(f"Archivo '{nombre_archivo}' creado exitosamente!")
# Out:
# Archivo 'sostenibilidad_bajo_cauca.xlsx' creado exitosamente!

# %%
# 2. Leer el archivo Excel recién creado
df_leido = pd.read_excel(nombre_archivo)
df_leido
# Out:
#   municipio              proyecto  beneficiarios            tema   año
# 0  Caucasia           Agua Segura           1200            agua  2023
# 1  El Bagre  Cultivos Sostenibles            800        cultivos  2022
# 2     Nechí       Educación Rural            500       educación  2023
# 3    Tarazá   Minería Responsable            950         minería  2021
# 4  Zaragoza  Talleres Ambientales            600  medio ambiente  2022

# %%
# 3. Visualización básica
print("\n--- Datos completos ---")
print(df_leido)
# Out:
# --- Datos completos ---
#   municipio              proyecto  beneficiarios            tema   año
# 0  Caucasia           Agua Segura           1200            agua  2023
# 1  El Bagre  Cultivos Sostenibles            800        cultivos  2022
# 2     Nechí       Educación Rural            500       educación  2023
# 3    Tarazá   Minería Responsable            950         minería  2021
# 4  Zaragoza  Talleres Ambientales            600  medio ambiente  2022

# %%
print("\n--- Resumen estadístico ---")
print(df_leido.describe())
# Out:
# --- Resumen estadístico ---
#        beneficiarios         año
# count       5.000000     5.00000
# mean      810.000000  2022.20000
# std       279.284801     0.83666
# min       500.000000  2021.00000
# 25%       600.000000  2022.00000
# 50%       800.000000  2022.00000
# 75%       950.000000  2023.00000
# max      1200.000000  2023.00000

# %%
print("\n--- Beneficiarios por municipio ---")
print(df_leido[['municipio', 'beneficiarios']].sort_values('beneficiarios', ascending=False))
# Out:
# --- Beneficiarios por municipio ---
#   municipio  beneficiarios
# 0  Caucasia           1200
# 3    Tarazá            950
# 1  El Bagre            800
# 4  Zaragoza            600
# 2     Nechí            500

# %%
print("\n--- Proyectos por año ---")
print(df_leido['año'].value_counts().sort_index())
# Out:
# --- Proyectos por año ---
# año
# 2021    1
# 2022    2
# 2023    2
# Name: count, dtype: int64

# %%
# 4. Visualización gráfica (opcional)
import matplotlib.pyplot as plt

# Gráfico de barras: Beneficiarios por proyecto
df_leido.plot(kind='bar', x='proyecto', y='beneficiarios', legend=False)
plt.title('Beneficiarios por proyecto en el Bajo Cauca')
plt.ylabel('Número de beneficiarios')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(alpha=0.3)
plt.savefig(r"C:\Users\marco\Downloads\beneficiarios_por_proyecto.png")
plt.show()

# %%
# Gráfico circular: Distribución por tema
df_leido.groupby('tema')['beneficiarios'].sum().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribución de beneficiarios por tema')
plt.ylabel('')
plt.show()

# %% [markdown]
#
# - **JSON (para datos semiestructurados):**

# %%
import json

# %%
import json

# Datos de ejemplo para investigación cualitativa en el Bajo Cauca Antioqueño
perfiles_comunitarios = {
    "proyecto": "Investigación cualitativa sobre dinámicas comunitarias en el Bajo Cauca Antioqueño",
    "institucion": "Universidad de Antioquia",
    "investigadores": ["Ana María Pérez", "Carlos Andrés Gómez", "Luisa Fernanda Ramírez"],
    "fecha_inicio": "2023-03-15",
    "municipios_estudio": ["Cáceres", "Caucasia", "El Bagre", "Nechí", "Tarazá", "Zaragoza"],
    "metodologia": {
        "tipo": "Investigación acción participativa",
        "tecnicas": ["Entrevistas semiestructuradas", "Grupos focales", "Observación participante", "Talleres comunitarios"],
        "muestra": 45,
        "duracion_meses": 12
    },
    "perfiles_participantes": [
        {
            "id": "PC001",
            "nombre": "Doña Rosa",
            "edad": 58,
            "genero": "femenino",
            "municipio": "Cáceres",
            "rol_comunitario": "Líder de asociación de mujeres",
            "temas_abordados": ["Economía familiar", "Violencia de género", "Cultivos alternativos"],
            "entrevistas_realizadas": 3
        },
        {
            "id": "PC002",
            "nombre": "Don Javier",
            "edad": 42,
            "genero": "masculino",
            "municipio": "El Bagre",
            "rol_comunitario": "Minero artesanal",
            "temas_abordados": ["Conflictos territoriales", "Economía extractiva", "Salud laboral"],
            "entrevistas_realizadas": 2
        },
        {
            "id": "PC003",
            "nombre": "María",
            "edad": 24,
            "genero": "femenino",
            "municipio": "Tarazá",
            "rol_comunitario": "Estudiante universitaria",
            "temas_abordados": ["Educación rural", "Migración juvenil", "Uso de tecnologías"],
            "entrevistas_realizadas": 1
        }
    ],
    "hallazgos_preliminares": {
        "economia": "Dependencia crítica de actividades extractivas con necesidad de diversificación",
        "seguridad": "Presencia de múltiples actores armados que condicionan la vida cotidiana",
        "genero": "Fortalecimiento de redes de mujeres como estrategia de resistencia",
        "juventud": "Altos índices de migración hacia centros urbanos por falta de oportunidades"
    },
    "notas_metodologicas": "Todos los participantes firmaron consentimiento informado. Se utilizaron pseudónimos para proteger identidades."
}

# Crear el archivo JSON
with open('perfiles_comunitarios.json', 'w', encoding='utf-8') as archivo:
    json.dump(perfiles_comunitarios, archivo, ensure_ascii=False, indent=4)

print("Archivo 'perfiles_comunitarios.json' creado exitosamente.")
# Out:
# Archivo 'perfiles_comunitarios.json' creado exitosamente.

# %%
with open("perfiles_comunitarios.json") as file:
    comunidades = json.load(file)  # Ejemplo: datos de organizaciones locales

# %%
comunidades
# Out:
# {'proyecto': 'InvestigaciÃ³n cualitativa sobre dinÃ¡micas comunitarias en el Bajo Cauca AntioqueÃ±o',
#  'institucion': 'Universidad de Antioquia',
#  'investigadores': ['Ana MarÃ\xada PÃ©rez',
#   'Carlos AndrÃ©s GÃ³mez',
#   'Luisa Fernanda RamÃ\xadrez'],
#  'fecha_inicio': '2023-03-15',
#  'municipios_estudio': ['CÃ¡ceres',
#   'Caucasia',
#   'El Bagre',
#   'NechÃ\xad',
#   'TarazÃ¡',
#   'Zaragoza'],
#  'metodologia': {'tipo': 'InvestigaciÃ³n acciÃ³n participativa',
#   'tecnicas': ['Entrevistas semiestructuradas',
#    'Grupos focales',
#    'ObservaciÃ³n participante',
#    'Talleres comunitarios'],
#   'muestra': 45,
#   'duracion_meses': 12},
#  'perfiles_participantes': [{'id': 'PC001',
#    'nombre': 'DoÃ±a Rosa',
#    'edad': 58,
#    'genero': 'femenino',
#    'municipio': 'CÃ¡ceres',
#    'rol_comunitario': 'LÃ\xadder de asociaciÃ³n de mujeres',
#    'temas_abordados': ['EconomÃ\xada familiar',
#     'Violencia de gÃ©nero',
#     'Cultivos alternativos'],
# ...

# %%
import pandas as pd
import json

# 1. Leer el archivo JSON
with open('perfiles_comunitarios.json', 'r', encoding='utf-8') as file:
    data = json.load(file)
# Out:
#       id      nombre  edad     genero municipio  \
# 0  PC001   Doña Rosa    58   femenino   Cáceres
# 1  PC002  Don Javier    42  masculino  El Bagre
# 2  PC003       María    24   femenino    Tarazá
#
#                   rol_comunitario  \
# 0  Líder de asociación de mujeres
# 1                Minero artesanal
# 2        Estudiante universitaria
#
#                                      temas_abordados  entrevistas_realizadas
# 0  [Economía familiar, Violencia de género, Culti...                       3
# 1  [Conflictos territoriales, Economía extractiva...                       2
# 2  [Educación rural, Migración juvenil, Uso de te...                       1

# %%
data.keys()
# Out:
# dict_keys(['proyecto', 'institucion', 'investigadores', 'fecha_inicio', 'municipios_estudio', 'metodologia', 'perfiles_participantes', 'hallazgos_preliminares', 'notas_metodologicas'])

# %%
# 2. Extraer los perfiles participantes y convertirlos a DataFrame
df_perfiles = pd.DataFrame(data['perfiles_participantes'])
df_perfiles

# %%
# 3. Normalizar la columna de temas abordados (para análisis cualitativo)
df_perfiles['temas_abordados'] = df_perfiles['temas_abordados'].apply(lambda x: ', '.join(x))

# 4. Añadir metadatos del proyecto como columnas (opcional)
df_perfiles['proyecto'] = data['proyecto']
df_perfiles['municipios_estudio'] = ', '.join(data['municipios_estudio'])

# 5. Crear un DataFrame aparte para los hallazgos preliminares
df_hallazgos = pd.DataFrame.from_dict(data['hallazgos_preliminares'], orient='index', columns=['descripcion'])

# 6. Mostrar los DataFrames resultantes
print("\nDataFrame de Perfiles Comunitarios:")
print(df_perfiles.head())

print("\nDataFrame de Hallazgos Preliminares:")
print(df_hallazgos)

# 7. Opcional: Guardar como CSV para análisis cualitativo
df_perfiles.to_csv('perfiles_comunitarios.csv', index=False, encoding='utf-8-sig')
df_hallazgos.to_csv('hallazgos_preliminares.csv', index=True, encoding='utf-8-sig')

# 8. Análisis básico (para la master class)
print("\nResumen estadístico:")
print(df_perfiles.describe(include='all'))

print("\nConteo por municipio:")
print(df_perfiles['municipio'].value_counts())

# %% [markdown]
#
#   - *Ejercicio práctico:* Cargar un archivo CSV de ejemplo con datos ficticios sobre proyectos de desarrollo en la región.

# %% [markdown]
# ## **3. Librerías Clave (10 min)**

# %% [markdown]
#
# **Objetivo:** Introducir herramientas para procesar y visualizar datos cualitativos con enfoque regional.

# %% [markdown]
# - **Pandas (estructuración de datos):**
#   - Filtrar respuestas de entrevistas por municipio:

# %% [markdown]
#     ```python
#     datos[datos["municipio"] == "El Bagre"]  # Ejemplo aplicado
#     ```

# %% [markdown]
#
# - **Procesamiento de Lenguaje Natural (NLTK/spaCy):**
#   - Extraer palabras clave de informes sobre sostenibilidad:
#     ```python
#     from nltk import word_tokenize
#     tokens = word_tokenize("La minería ilegal afecta los ríos del Bajo Cauca")  # Tokenización
#     ```
#   - *Demo rápida:* Análisis de sentimientos en discursos sobre desarrollo rural (`TextBlob`).
# - **Visualización (Matplotlib/WordCloud):**
#   - Nube de palabras con términos recurrentes en proyectos ambientales:
#     ```python
#     from wordcloud import WordCloud
#     wordcloud = WordCloud().generate(texto)  # Usar texto cargado previamente
#     ```
#   - *Ejercicio práctico:* Generar un gráfico de barras con la frecuencia de temas en entrevistas (ej: "agua", "tierra", "violencia").
#
# ---
#
# #### **Cierre del Módulo (5 min)**
# - **Recapitulación:**
#   - "Hoy aprendimos a estructurar datos cualitativos, cargar archivos locales y usar librerías para análisis temático".
# - **Puente al siguiente módulo:**
#   - *"En la siguiente sesión, aplicaremos esto para analizar entrevistas reales sobre conflictos socioambientales en la región."*
#
# ---
#
# ### **Recomendaciones para el Facilitador:**
# - **Contextualizar siempre:** Usar ejemplos hipotéticos pero realistas (ej: dataset llamado "sostenibilidad_bajo_cauca.csv").
# - **Incluir datos locales:** Si es posible, mostrar un fragmento de entrevista real (anonimizada) de un proyecto UdeA.
# - **Resolver dudas:** Preguntar: *"¿Cómo ven aplicable esto en sus investigaciones actuales?"*.
#
# **Material de apoyo:**
# - Proporcionar un cuaderno de Jupyter con los ejemplos y ejercicios preescritos.
#
# ¿Necesitas ajustar los ejemplos para incluir alguna temática específica del territorio?

# %% [markdown]
# # **3. Análisis Cualitativo con Python (1.5 horas)**

# %% [markdown]
# - **Preprocesamiento de textos:**
#   - Tokenización, limpieza de datos (stopwords, lematización).
#   - Ejemplo práctico: Análisis de entrevistas o discursos políticos del Bajo Cauca.

# %% [markdown]
#
# - **Técnicas de análisis:**
#   - Frecuencia de términos.
#   - Análisis de sentimientos con `TextBlob`.
#   - Codificación automatizada (ej: identificación de categorías temáticas).

# %% [markdown]
# # **3. Análisis Cualitativo con Python (1.5 horas)**
# **Enfoque:** Aplicación de técnicas computacionales para investigaciones sobre desarrollo, conflicto y sostenibilidad en el Bajo Cauca.

# %% [markdown]
# #### **1. Preprocesamiento de Textos (40 min)**
# **Objetivo:** Preparar datos textuales (entrevistas, discursos, informes) para análisis automatizado.

# %% [markdown]
# **A. Tokenización y Limpieza Básica**
# - **Ejemplo con entrevistas sobre minería ilegal:**

# %%
from nltk.tokenize import word_tokenize
import nltk
texto = "La minería ilegal en el Bajo Cauca contamina los ríos y afecta a las comunidades"
tokens = word_tokenize(texto.lower())  # Convertir a minúsculas y dividir en palabras
print(tokens)  # Resultado: ['la', 'minería', 'ilegal', 'en', 'el', 'bajo', 'cauca', ...]
nltk.download('punkt')

# %% [markdown]
#
#
# **B. Eliminación de Stopwords (palabras irrelevantes)**

# %%
  
from nltk.corpus import stopwords
stopwords_es = stopwords.words('spanish') + ["bajo", "cauca"]  # Añadir términos locales no relevantes
tokens_limpios = [word for word in tokens if word not in stopwords_es]
print(tokens_limpios)  # Resultado: ['minería', 'ilegal', 'contamina', 'ríos', 'afecta', 'comunidades']

# %% [markdown]
#
#
# **C. Lematización (reducir palabras a su raíz)**

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')
lemas = [stemmer.stem(word) for word in tokens_limpios]
print(lemas)  # Resultado: ['miner', 'ilegal', 'contamin', 'ríos', 'afect', 'comun']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from nltk.stem import SnowballStemmer
#       2 stemmer = SnowballStemmer('spanish')
# ----> 3 lemas = [stemmer.stem(word) for word in tokens_limpios]
#       4 print(lemas)  # Resultado: ['miner', 'ilegal', 'contamin', 'ríos', 'afect', 'comun']
#
# NameError: name 'tokens_limpios' is not defined

# %% [markdown]
#
#
# **Ejercicio Práctico:**
# - Procesar un fragmento de discurso político local (ej: declaraciones de líderes sobre desarrollo rural).
# - **Dataset sugerido:** Texto de un informe sobre conflictos de tierra en el Bajo Cauca (proporcionado por el facilitador).
#
# ---

# %% [markdown]
# #### **2. Técnicas de Análisis (50 min)**

# %% [markdown]
# **A. Frecuencia de Términos**
# - **Identificar temas clave en proyectos de sostenibilidad:**
#   ```python
#   from collections import Counter
#   frecuencias = Counter(tokens_limpios)
#   print(frecuencias.most_common(5))  # Ejemplo: [('minería', 12), ('agua', 8), ('violencia', 6)]
#   ```

# %% [markdown]
# **B. Análisis de Sentimientos con `TextBlob`**
# - **Evaluar tono en noticias o discursos:**
#   ```python
#   from textblob import TextBlob
#   texto = "La deforestación en el Bajo Cauca es una tragedia ambiental"
#   analisis = TextBlob(texto).translate(to='en')  # TextBlob funciona mejor en inglés
#   print(analisis.sentiment.polarity)  # Rango: -1 (negativo) a 1 (positivo)
#   ```

# %% [markdown]
#
#   - *Nota:* Traducir al inglés puede afectar precisión. Alternativa: Usar librerías en español como `pysentimiento`.

# %% [markdown]
# **C. Codificación Automatizada (Identificación de Categorías Temáticas)**
# - **Ejemplo con entrevistas sobre economía local:**
#   ```python
#   categorias = {"medio_ambiente": ["río", "contaminación", "deforestación"],
#                 "economía": ["cultivos", "ingresos", "minería"]}
#
#   texto_entrevista = "Los cultivos de cacao son afectados por la contaminación del río"
#   palabras = texto_entrevista.lower().split()
#
#   temas = []
#   for categoria, palabras_clave in categorias.items():
#       if any(palabra in palabras for palabra in palabras_clave):
#           temas.append(categoria)
#   print(temas)  # Resultado: ['medio_ambiente', 'economía']
#   ```

# %% [markdown]
# **Ejercicio Práctico:**
# 1. Analizar un conjunto de tweets o noticias locales sobre un proyecto de desarrollo.
# 2. Generar:
#    - Lista de términos frecuentes.
#    - Gráfico de sentimiento (positivo/negativo).
#    - Categorización automática por temas predefinidos.
#
# ---

# %% [markdown]
# #### **Cierre del Módulo (5 min)**
# - **Discusión grupal:**
#   - *"¿Cómo podrían aplicar estas técnicas en sus investigaciones actuales?"*
#   - Ejemplos reales:
#     - Análisis de discursos en talleres comunitarios.
#     - Codificación automática de entrevistas sobre reubicación por violencia.
# - **Puente al siguiente módulo:**
#   - *"Ahora que hemos extraído insights de los textos, aprenderemos a visualizarlos efectivamente."*
#
# ---

# %% [markdown]
# ### **Recomendaciones para el Facilitador:**
# - **Enfatizar el contexto local:** Usar datos reales (anonimizados) de investigaciones UdeA en Caucasia.
# - **Advertencias:**
#   - Limitar el uso de traducción automática en análisis de sentimientos.
#   - Recalcar que la codificación automatizada requiere ajustes manuales para precisión.
# - **Material adicional:**
#   - Proporcionar un diccionario de categorías temáticas predefinidas (ej: "conflicto", "sostenibilidad").
#
# ¿Necesitas adaptar los ejemplos a un tipo específico de dato cualitativo (ej: actas de reuniones comunitarias)?

# %% [markdown]
# ### **4. Visualización y Presentación de Resultados (1 hora)**
# - Gráficos de barras para frecuencias de palabras.
# - Nubes de palabras (`WordCloud`).
# - Mapas conceptuales simples con `NetworkX`.
# - Exportación de resultados (informes en PDF, HTML o interactivos).

# %% [markdown]
# ### **4. Visualización y Presentación de Resultados (1 hora)**
# **Tema central:** Comunicación efectiva de hallazgos sobre sostenibilidad y desarrollo territorial del Bajo Cauca.
#
# ---
#
# #### **1. Gráficos de Barras para Frecuencias de Palabras (15 min)**
# **Objetivo:** Mostrar términos clave en proyectos de desarrollo local.
#
# - **Ejemplo con datos de talleres comunitarios:**
#   ```python
#   import matplotlib.pyplot as plt
#   from collections import Counter
#
#   # Datos de ejemplo (términos extraídos de entrevistas)
#   temas = ["agua", "minería", "agua", "cultivos", "violencia", "agua", "cultivos"]
#   frecuencias = Counter(temas)
#
#   # Crear gráfico
#   plt.bar(frecuencias.keys(), frecuencias.values(), color='#2E8B57')  # Verde sostenibilidad
#   plt.title("Temas recurrentes en proyectos de desarrollo territorial (Bajo Cauca)", pad=20)
#   plt.xlabel("Temas clave")
#   plt.ylabel("Frecuencia")
#   plt.xticks(rotation=45)
#   plt.show()
#   ```
#   - **Personalización:**
#     - Usar colores temáticos (verdes para ambiente, azules para agua).
#     - Añadir títulos en español con contexto local.
#
# ---
#
# #### **2. Nubes de Palabras (`WordCloud`) (20 min)**
# **Objetivo:** Visualizar patrones en discursos sobre sostenibilidad.
#
# - **Código para análisis de políticas públicas:**
#   ```python
#   from wordcloud import WordCloud
#   import matplotlib.pyplot as plt
#
#   texto = """
#     sostenibilidad desarrollo territorial agua minería ilegal cultivos cacao
#     reforestación comunidades educación rural conflicto tierra
#   """  # Texto puede venir de informes o entrevistas
#
#   wordcloud = WordCloud(
#       width=800, height=400,
#       background_color='white',
#       colormap='Greens',  # Paleta temática
#       stopwords=["ilegal"]  # Personalizar stopwords
#   ).generate(texto)
#
#   plt.imshow(wordcloud, interpolation='bilinear')
#   plt.axis("off")
#   plt.title("Prioridades en desarrollo territorial - Bajo Cauca", fontsize=14, pad=20)
#   plt.show()
#   ```
#   - **Ejercicio práctico:**
#     - Generar una nube de palabras con fragmentos de:
#       - Informes de la Gobernación de Antioquia sobre el Bajo Cauca.
#       - Transcripciones de talleres con líderes sociales.
#
# ---
#
# #### **3. Mapas Conceptuales con `NetworkX` (15 min)**
# **Objetivo:** Mapear relaciones entre actores y temas en proyectos territoriales.
#
# - **Ejemplo: Red de actores del desarrollo:**
#   ```python
#   import networkx as nx
#   import matplotlib.pyplot as plt
#
#   G = nx.Graph()
#   G.add_nodes_from(["UAO", "Gobernación", "JAC", "Mineros"])  # Actores clave
#   G.add_edges_from([
#       ("UAO", "Gobernación", {"weight": 3}),  # Cooperación fuerte
#       ("UAO", "JAC", {"weight": 5}),         # Trabajo directo con comunidades
#       ("JAC", "Mineros", {"weight": 1})      # Interacción débil
#   ])
#
#   pos = nx.spring_layout(G)
#   nx.draw(G, pos, with_labels=True, node_color='#4F7942', font_weight='bold',
#           node_size=2000, edge_color='gray', width=[d['weight'] for _, _, d in G.edges(data=True)])
#   plt.title("Red de actores en proyectos de desarrollo sostenible", pad=20)
#   plt.show()
#   ```
#   - **Aplicación:**
#     - Visualizar alianzas institucionales.
#     - Mapear conflictos entre actores (ej: comunidades vs. empresas mineras).
#
# ---
#
# #### **4. Exportación de Resultados (10 min)**
# **Objetivo:** Compartir hallazgos con comunidades y tomadores de decisiones.
#
# - **A. Reporte en PDF (usando `matplotlib` y `FPDF`):**

# %%
from fpdf import FPDF
import matplotlib.pyplot as plt

# Generar gráfico (ej: frecuencia de temas)
plt.bar(["Agua", "Tierra"], [15, 8])
plt.savefig("grafico.png")

# Crear PDF
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)
pdf.cell(200, 10, txt="Informe de análisis cualitativo - Bajo Cauca", ln=True, align='C')
pdf.image("grafico.png", x=50, w=100)
pdf.output("informe_desarrollo_territorial.pdf")

# %% [markdown]
#
#
# - **B. Dashboard interactivo (opcional con `Streamlit`):**

# %%
import streamlit as st
st.title("Indicadores de Sostenibilidad - Bajo Cauca")
st.write("Frecuencia de temas en proyectos:")
st.bar_chart({"Agua": 15, "Tierra": 8})  # Datos simulados
  # Este script está pensado para ejecutarse con `streamlit run nombre_del_script.py`
  # Si lo ejecutas directamente en Jupyter Notebook, Streamlit mostrará advertencias como "missing ScriptRunContext".
  # Para evitar el error, ejecuta el script desde la terminal con:
  # streamlit run nombre_del_script.py

# %%
# Si solo quieres mostrar los datos en Jupyter, usa matplotlib o pandas para visualizar.
# Ejemplo alternativo para Jupyter:
import matplotlib.pyplot as plt
plt.bar(["Agua", "Tierra"], [15, 8])
plt.savefig(r"C:\Users\marco\Downloads\frecuencia_temas.png")
plt.show()

# %% [markdown]
#
#   - *Demo rápida:* Mostrar ejemplo desplegado en la web.
#
# ---

# %% [markdown]
# ## **Cierre del Módulo (5 min)**

# %% [markdown]
# - **Reflexión grupal:**
#   - *"¿Qué visualización les parece más útil para comunicar sus hallazgos a comunidades locales?"*

# %% [markdown]
#
# - **Recomendaciones finales:**
#   - Usar gráficos sencillos para audiencias no técnicas.
#   - Incluir mapas georreferenciados (opcional con `folium` si hay datos espaciales).

# %% [markdown]
# ### **Material de Apoyo**
# - Carpeta con:
#   - Dataset de ejemplo: `informe_sostenibilidad_bajo_cauca.txt`.
#   - Códigos base para cada visualización.
#   - Guía de colores accesibles (ej: evitar rojos/verdes para daltonismo).

# %% [markdown]
# **Nota:** Adaptar los ejemplos a proyectos reales de la Universidad de Antioquia en la región, como:

# %% [markdown]
#
# - Análisis de conflictos por uso de tierra.
# - Evaluación de programas de desarrollo rural.

# %% [markdown]
# ### **5. Cierre y Discusión (30 min)**
# - Retroalimentación y casos de aplicación en proyectos reales.
# - Recomendaciones de recursos (cursos, libros, repositorios).
# - Red de colaboración entre investigadores.

# %% [markdown]
# ### **5. Cierre y Discusión (30 min)**
# **Objetivo:** Consolidar aprendizajes, fomentar la aplicación práctica y crear redes de colaboración entre investigadores del Bajo Cauca.
#
# ---

# %% [markdown]
# #### **1. Retroalimentación y Casos de Aplicación (15 min)**
# **Dinámica participativa:**
# - **Lluvia de ideas rápida:**
#   - Pregunta disparadora: *"¿Cómo aplicarían lo aprendido hoy en sus investigaciones actuales sobre sostenibilidad y desarrollo territorial?"*
#   - Ejemplos guiados (si hay silencio):
#     - *"Análisis de discursos en reuniones de JAC sobre conflictos ambientales"*.
#     - *"Codificación automatizada de entrevistas a víctimas de desplazamiento"*.
#
# - **Socialización de un caso real (opcional):**
#   - Invitar a un investigador local (ej: profesor UdeA) a compartir cómo usa Python en su trabajo.
#   - **Demo breve (5 min):** Mostrar un análisis real (anonimizado) de datos del Bajo Cauca, por ejemplo:
#     - Nube de palabras de informes sobre minería ilegal.
#     - Red de actores de un proyecto de desarrollo rural.
#
# ---

# %% [markdown]
# #### **2. Recomendaciones de Recursos (10 min)**
# **Kit de supervivencia para seguir aprendiendo:**
# - **Cursos gratuitos:**
#   - *"Python para Ciencias Sociales"* (Coursera/edX).
#   - *"Procesamiento de Lenguaje Natural con spaCy"* (YouTube, freeCodeCamp).
# - **Libros:**
#   - *"Análisis de Datos Cualitativos con Python"* (ejemplos en español).
#   - *"Investigación Digital en Contextos de Conflicto"* (casos latinoamericanos).
# - **Repositorios útiles:**
#   - GitHub: Búsqueda con etiquetas `#qualitative-research` + `#python`.
#   - Datos abiertos: Portal de la [Gobernación de Antioquia](https://www.antioquia.gov.co/) sobre proyectos en el Bajo Cauca.
#
# **Material compartido:**
# - Enlace a carpeta con:
#   - Cuadernos de Jupyter usados en el taller.
#   - Dataset de ejemplo (entrevistas simuladas sobre desarrollo territorial).
#   - Guía rápida de comandos Python para análisis cualitativo.
#
# ---

# %% [markdown]
# #### **3. Red de Colaboración (5 min)**
# **Acciones concretas:**
# - **Crear un grupo de Telegram/WhatsApp:**
#   - Para resolver dudas, compartir avances y datos.
#   - *Ejemplo de nombre:* *"Python para el Desarrollo Territorial - UdeA Caucasia"*.
# - **Convocatoria a colaborar:**
#   - Invitar a postular proyectos conjuntos (ej: análisis de datos para informes locales).
#   - Ofrecer mentorías mensuales virtuales (opcional).
#
# ---

# %% [markdown]
# #### **Palabras de Cierre (5 min)**
# - **Mensaje clave:**
#   - *"Python es una herramienta para potenciar su trabajo de campo, no para reemplazar el análisis crítico que ustedes como investigadores aportan"*.
# - **Agradecimiento y contacto:**
#   - Compartir correo del facilitador para consultas.
#   - Anunciar futuras sesiones (ej: taller avanzado con datos geoespaciales).
#
# ---

# %% [markdown]
# ### **Recomendaciones para el Facilitador:**
# - **Inclusión:** Pedir feedback anónimo vía formulario Google (2 preguntas clave: *¿Qué fue más útil? ¿Qué faltó?*).
# - **Inspiración:** Cerrar con una cita relevante:
#   *"Los datos no son solo números o palabras; son historias del territorio que ustedes ayudan a contar"*.
#
# **Material adicional:**
# - Plantilla de correo para mantener el contacto post-taller (ej: recordatorios de recursos).
#
# ¿Quieres ajustar algún elemento para integrar a instituciones aliadas (ej: ONGs locales)?

# %% [markdown]
# ---
#
# ## **Metodología**
# - **Enfoque práctico:** Ejercicios guiados con datos reales o simulados del contexto del Bajo Cauca.
# - **Trabajo colaborativo:** Discusión en grupos sobre aplicaciones específicas.
# - **Materiales:** Cuadernos de Jupyter compartidos, datasets de ejemplo (ej: transcripciones de entrevistas).

# %% [markdown]
# ---
#
# ## **Requisitos Técnicos**
# - Computador con Python 3.x instalado (o acceso a Google Colab).
# - Cuenta de GitHub para acceso a repositorio de materiales.
# - Conocimientos básicos de investigación cualitativa (no se requiere experiencia previa en programación).
#
# ---

# %% [markdown]
# ## **Instructor(es)**
# - Perfil preferible: Experto en Python aplicado a ciencias sociales con conocimiento del contexto regional.
# - Posible colaboración con grupos de investigación de la UdeA (ej: Instituto de Estudios Regionales).
#
# ---

# %% [markdown]
# ## **Evaluación**
# - Encuesta de satisfacción.
# - Entrega de un ejercicio aplicado (opcional para certificación).
#
# ---

# %% [markdown]
# **Nota:** Este taller puede adaptarse a necesidades específicas, como el análisis de conflictos socioambientales o memoria histórica en la región.

# %% [markdown]
# ¿Necesitas ajustes o más detalles en alguna sección?
