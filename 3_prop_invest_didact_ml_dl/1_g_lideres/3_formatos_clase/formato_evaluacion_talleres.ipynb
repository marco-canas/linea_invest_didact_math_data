# %% [markdown]
# # Formato de evaluación de los talleres de formación en habilidades digitales

# %% [markdown]
# Aquí tienes un formato de Google Form ajustado a tu **metodología mixta (cuasi-experimental y cualitativa)**, integrando variables específicas para medir el impacto de los talleres según tu diseño de investigación:
#
# ---
#
# # **EVALUACIÓN DE TALLERES - HABILIDADES DIGITALES G-LÍDERES UdeA**
# *(Pre/Post-Taller)*
#
# ### **Sección 1: Datos de Identificación**
# 1. **Identificador único** (asignado por el equipo investigador):
#    - *Texto corto*
# 2. **Fecha del taller**:
#    - *Fecha*
# 3. **Tipo de evaluación**:
#    - ☐ Pre-taller (línea base)
#    - ☐ Post-taller (impacto inmediato)
#    - ☐ Seguimiento (3 meses después)
#
# ---
#
# ### **Sección 2: Variables Cuantitativas** *(Escala Likert 1-5)*
# **A. Competencias Técnicas**
# 4. **Autopercepción de habilidad en [tema del taller, ej: Power BI] antes/después del taller**:
#    - 1 (Nulo) ⭘ 2 ⭘ 3 ⭘ 4 ⭘ 5 (Avanzado)
# 5. **Capacidad para resolver problemas empresariales con herramientas digitales**:
#    - 1 ⭘ 2 ⭘ 3 ⭘ 4 ⭘ 5
#
# **B. Variables de Satisfacción**
# 6. **La metodología (teórico-práctica) facilitó mi aprendizaje**:
#    - 1 ⭘ 2 ⭘ 3 ⭘ 4 ⭘ 5
# 7. **El instructor demostró dominio del tema**:
#    - 1 ⭘ 2 ⭘ 3 ⭘ 4 ⭘ 5
#
# **C. Infraestructura** *(Relacionado con tus desafíos identificados)*
# 8. **Acceso a recursos tecnológicos durante el taller**:
#    - 1 (Muy limitado) ⭘ 3 ⭘ 5 (Óptimo)
#
# ---
#
# ### **Sección 3: Variables Cualitativas**
# 9. **Describa un caso práctico donde aplicaría lo aprendido en su contexto laboral/académico**:
#    - *Texto largo*
# 10. **Principales dificultades enfrentadas durante el taller**: *(Opción múltiple + texto)*
#     - ☐ Conectividad a internet
#     - ☐ Complejidad del software
#     - ☐ Falta de acompañamiento
#     - ☐ Otro: _________
#
# ---
#
# ### **Sección 4: Indicadores de Impacto** *(Post-taller y seguimiento)*
# 11. **¿Ha utilizado las habilidades aprendidas en proyectos reales?**:
#     - ☐ Sí → *Describa brevemente*
#     - ☐ No → *¿Qué lo impidió?*
# 12. **Nivel de confianza para recomendar este taller a colegas**:
#     - 0 (Nada) ⭘ 5 (Totalmente)
#
# ---
#
# ### **Sección 5: Preguntas de Control** *(Para análisis estadístico)*
# 13. **Horas de práctica independiente después del taller**:
#     - *Número entero*
# 14. **Participación en otros programas de formación digital**:
#     - ☐ Sí ☐ No
#
# ---
#
# ### **Configuraciones Clave en Google Forms**
# - **Lógica condicional**:
#   - Si en Q3 selecciona "Pre-taller", ocultar Sección 4.
#   - Si en Q11 selecciona "Sí", mostrar campo de descripción.
# - **Validación de respuestas**:
#   - Q4 y Q5 obligatorias para comparar pre/post con pruebas t-student.
# - **Exportación a CSV**: Para análisis en Python (pandas, scipy.stats).
#
# ---
#
# ### **Variables Vinculadas a tu Marco Teórico**
# | **Variable**          | **Relación con Marco**                                  | **Tipo de Análisis** |
# |------------------------|-------------------------------------------------------|----------------------|
# | Autopercepción de habilidades | Teoría del Capital Humano (Becker, 1964) | ANOVA (pre/post) |
# | Dificultades de infraestructura | Brecha digital (Pérez & Ramírez, 2021) | Codificación temática |
# | Aplicación en proyectos reales | Teoría Desarrollo Organizacional (Lewin, 1947) | Estadística descriptiva |
#
# ---
#
# ### **Ejemplo de Preguntas de Investigación Evaluables**
# 1. *"¿Existe diferencia significativa (p<0.05) en la autopercepción de habilidades entre pre y post-taller?"*
#    - Análisis: Prueba t pareada con librerías Python (scipy.stats).
# 2. *"¿Cuáles son las barreras recurrentes para la aplicación práctica según regiones?"*
#    - Análisis: Nube de palabras con respuestas cualitativas (NLTK).
#
# **Recomendación**: Usa **Google Forms + Google Sheets** para recolectar datos y luego exportar a Python/R para análisis avanzado. ¿Necesitas ayuda para diseñar el script de análisis?
